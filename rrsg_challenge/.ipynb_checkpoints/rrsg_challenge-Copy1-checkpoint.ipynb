# %%
# Import package
# %matplotlib notebook
import h5py
import numpy as np
import sigpy.plot as pl
import sigpy as sp
import cfl
import matplotlib.pyplot as plt

# %%
#read dataset: brain dataset
h5_dataset_brain = h5py.File('rawdata_brain_radial_96proj_12ch.h5', 'r')

# %%
kl = kspace_low_dim.transpose(1,2,0)[:,:,None,:]

# %%
kl.shape
# Out:
# (300, 300, 1, 12)

# %%
cfl.writecfl(array=kl,name="low_res")

# %%
sens = cfl.readcfl("sens_low")

# %%
sens_map = sens[:,:,0,:,0].transpose(2,0,1)

# %%
pl.ImagePlot(sens_map)
# Out:
# <img src="data:image/png;base64,..." width="431.8749935645611">

# %%
pl.ImagePlot(sens)
# Out:
# <img src="data:image/png;base64,..." width="431.8749935645611">

# %%
rawdata.shape
# Out:
# (1, 512, 96, 12)

# %%
h5_dataset_rawdata_name = list(h5_dataset_brain.keys())[0]
h5_dataset_trajectory_name = list(h5_dataset_brain.keys())[1]

trajectory = h5_dataset_brain.get(h5_dataset_trajectory_name).value
rawdata = h5_dataset_brain.get(h5_dataset_rawdata_name).value

# %%
gpu_number = 0

# %%
type(phase)
# Out:
# cupy.core.core.ndarray

# %%
coor = trajectory[:2,:,:].transpose((1,2,0))
phase = np.exp(1j*np.pi*(0.1)*coor[:,:,0][None,:,:])
# phase = sp.backend.to_device(phase,gpu_number)
rawdata_brain = rawdata[0,:,:,:].transpose((2,0,1))*phase
coor = sp.backend.to_device(coor,gpu_number)
rawdata_brain = sp.backend.to_device(rawdata_brain,gpu_number)
# image = cfl.readcfl("img_igrid_brain")
# image_sos = sp.util.rss(image,3)
# sens_maps = image[:,:,0,:]/image_sos
# sens_maps_t = sens_maps.transpose((2,0,1))
# sens_maps_t = sp.backend.to_device(sens_maps_t,gpu_number)

# %%
rate = 0.25
cc1 = coor[256-256*rate:256+256*rate,:,:]
raw_low = rawdata_brain[:,256-256*rate:256+256*rate,:]

# %%
type(raw_low)
# Out:
# cupy.core.core.ndarray

# %%
raw_1 = raw_low[0,:,:][None,:,:]

# %%
NUFFT_low.ishape
# Out:
# [1, 75, 75]

# %%
import cupy as cp

# %%
kspace_low_dim = cp.zeros((12,300,300),dtype=cp.complex)

# %%
for j in range(12):
    print(j)
    raw_1 = raw_low[j,:,:][None,:,:]
    NUFFT_low = sp.linop.NUFFT((1,int(300*rate),int(300*rate)),cc1)
    lamda_l2 = 0.1
    proxg_l2 = sp.prox.L2Reg((1,int(300*rate),int(300*rate)),lamda_l2)
    img_rec_loww = sp.app.LinearLeastSquares(NUFFT_low,raw_1,proxg=proxg_l2,max_iter=100).run()
    kspace_low_dim[j,150-38:150+37,150-38:150+37] = sp.fft(img_rec_loww)[0,:,:]
# Out:
# MaxEig:   0%|          | 0/30 [00:00<?, ?it/s]
#
# MaxEig:   0%|          | 0/30 [00:00<?, ?it/s, max_eig=2.83E+02]
#
# MaxEig:   3%|▎         | 1/30 [00:00<00:01, 22.71it/s, max_eig=7.41E+01]
#
# MaxEig:   7%|▋         | 2/30 [00:00<00:01, 27.52it/s, max_eig=1.51E+02]
#
# MaxEig:  10%|█         | 3/30 [00:00<00:00, 31.41it/s, max_eig=1.57E+02]
#
# MaxEig:  13%|█▎        | 4/30 [00:00<00:00, 33.76it/s, max_eig=1.57E+02]
#
# MaxEig:  17%|█▋        | 5/30 [00:00<00:00, 41.64it/s, max_eig=1.57E+02]
#
# MaxEig:  17%|█▋        | 5/30 [00:00<00:00, 41.64it/s, max_eig=1.57E+02]
#
# MaxEig:  20%|██        | 6/30 [00:00<00:00, 41.64it/s, max_eig=1.57E+02]
# 0
# MaxEig:  23%|██▎       | 7/30 [00:00<00:00, 41.64it/s, max_eig=1.57E+02]
#
# MaxEig:  27%|██▋       | 8/30 [00:00<00:00, 41.64it/s, max_eig=1.57E+02]
#
# MaxEig:  30%|███       | 9/30 [00:00<00:00, 41.64it/s, max_eig=1.57E+02]
#
# MaxEig:  33%|███▎      | 10/30 [00:00<00:00, 41.83it/s, max_eig=1.57E+02]
#
# MaxEig:  33%|███▎      | 10/30 [00:00<00:00, 41.83it/s, max_eig=1.57E+02]
#
# MaxEig:  37%|███▋      | 11/30 [00:00<00:00, 41.83it/s, max_eig=1.57E+02]
#
# MaxEig:  40%|████      | 12/30 [00:00<00:00, 41.83it/s, max_eig=1.57E+02]
#
# MaxEig:  43%|████▎     | 13/30 [00:00<00:00, 41.83it/s, max_eig=1.57E+02]
#
# MaxEig:  47%|████▋     | 14/30 [00:00<00:00, 40.56it/s, max_eig=1.57E+02]
#
# MaxEig:  47%|████▋     | 14/30 [00:00<00:00, 40.56it/s, max_eig=1.57E+02]
#
# MaxEig:  50%|█████     | 15/30 [00:00<00:00, 40.56it/s, max_eig=1.57E+02]
#
# MaxEig:  53%|█████▎    | 16/30 [00:00<00:00, 40.56it/s, max_eig=1.57E+02]
#
# MaxEig:  57%|█████▋    | 17/30 [00:00<00:00, 40.56it/s, max_eig=1.57E+02]
#
# MaxEig:  60%|██████    | 18/30 [00:00<00:00, 40.56it/s, max_eig=1.57E+02]
#
# MaxEig:  63%|██████▎   | 19/30 [00:00<00:00, 41.69it/s, max_eig=1.57E+02]
#
# MaxEig:  63%|██████▎   | 19/30 [00:00<00:00, 41.69it/s, max_eig=1.57E+02]
#
# MaxEig:  67%|██████▋   | 20/30 [00:00<00:00, 41.69it/s, max_eig=1.57E+02]
#
# MaxEig:  70%|███████   | 21/30 [00:00<00:00, 41.69it/s, max_eig=1.57E+02]
#
# MaxEig:  73%|███████▎  | 22/30 [00:00<00:00, 41.69it/s, max_eig=1.57E+02]
#
# MaxEig:  77%|███████▋  | 23/30 [00:00<00:00, 41.69it/s, max_eig=1.57E+02]
#
# MaxEig:  80%|████████  | 24/30 [00:00<00:00, 42.18it/s, max_eig=1.57E+02]
#
# MaxEig:  80%|████████  | 24/30 [00:00<00:00, 42.18it/s, max_eig=1.57E+02]
#
# MaxEig:  83%|████████▎ | 25/30 [00:00<00:00, 42.18it/s, max_eig=1.57E+02]
#
# MaxEig:  87%|████████▋ | 26/30 [00:00<00:00, 42.18it/s, max_eig=1.57E+02]
#
# MaxEig:  90%|█████████ | 27/30 [00:00<00:00, 42.18it/s, max_eig=1.57E+02]
#
# MaxEig:  93%|█████████▎| 28/30 [00:00<00:00, 42.18it/s, max_eig=1.57E+02]
#
# MaxEig:  97%|█████████▋| 29/30 [00:00<00:00, 42.32it/s, max_eig=1.57E+02]
#
# MaxEig:  97%|█████████▋| 29/30 [00:00<00:00, 42.32it/s, max_eig=1.57E+02]
#
# MaxEig: 100%|██████████| 30/30 [00:00<00:00, 41.89it/s, max_eig=1.57E+02]
#
# LinearLeastSquares:   0%|          | 0/100 [00:00<?, ?it/s]
#
# LinearLeastSquares:   0%|          | 0/100 [00:00<?, ?it/s, resid=7.44E-01]
#
# LinearLeastSquares:   1%|          | 1/100 [00:00<00:04, 20.44it/s, resid=1.84E-01]
#
# LinearLeastSquares:   2%|▏         | 2/100 [00:00<00:03, 28.02it/s, resid=1.22E-01]
#
# LinearLeastSquares:   3%|▎         | 3/100 [00:00<00:03, 31.82it/s, resid=7.97E-02]
#
# LinearLeastSquares:   4%|▍         | 4/100 [00:00<00:02, 34.01it/s, resid=5.29E-02]
#
# LinearLeastSquares:   5%|▌         | 5/100 [00:00<00:02, 41.98it/s, resid=5.29E-02]
#
# LinearLeastSquares:   5%|▌         | 5/100 [00:00<00:02, 41.98it/s, resid=3.64E-02]
#
# LinearLeastSquares:   6%|▌         | 6/100 [00:00<00:02, 41.98it/s, resid=2.60E-02]
#
# LinearLeastSquares:   7%|▋         | 7/100 [00:00<00:02, 41.98it/s, resid=1.95E-02]
#
# LinearLeastSquares:   8%|▊         | 8/100 [00:00<00:02, 41.98it/s, resid=1.51E-02]
#
# LinearLeastSquares:   9%|▉         | 9/100 [00:00<00:02, 41.98it/s, resid=1.21E-02]
#
# LinearLeastSquares:  10%|█         | 10/100 [00:00<00:02, 41.45it/s, resid=1.21E-02]
#
# LinearLeastSquares:  10%|█         | 10/100 [00:00<00:02, 41.45it/s, resid=1.00E-02]
#
# LinearLeastSquares:  11%|█         | 11/100 [00:00<00:02, 41.45it/s, resid=8.45E-03]
#
# LinearLeastSquares:  12%|█▏        | 12/100 [00:00<00:02, 41.45it/s, resid=7.29E-03]
#
# LinearLeastSquares:  13%|█▎        | 13/100 [00:00<00:02, 41.45it/s, resid=6.40E-03]
#
# LinearLeastSquares:  14%|█▍        | 14/100 [00:00<00:02, 39.77it/s, resid=6.40E-03]
#
# LinearLeastSquares:  14%|█▍        | 14/100 [00:00<00:02, 39.77it/s, resid=5.70E-03]
#
# LinearLeastSquares:  15%|█▌        | 15/100 [00:00<00:02, 39.77it/s, resid=5.15E-03]
#
# LinearLeastSquares:  16%|█▌        | 16/100 [00:00<00:02, 39.77it/s, resid=4.70E-03]
#
# LinearLeastSquares:  17%|█▋        | 17/100 [00:00<00:02, 39.77it/s, resid=4.32E-03]
#
# LinearLeastSquares:  18%|█▊        | 18/100 [00:00<00:02, 39.77it/s, resid=4.01E-03]
#
# LinearLeastSquares:  19%|█▉        | 19/100 [00:00<00:01, 40.50it/s, resid=4.01E-03]
#
# LinearLeastSquares:  19%|█▉        | 19/100 [00:00<00:01, 40.50it/s, resid=3.74E-03]
#
# LinearLeastSquares:  20%|██        | 20/100 [00:00<00:01, 40.50it/s, resid=3.51E-03]
#
# LinearLeastSquares:  21%|██        | 21/100 [00:00<00:01, 40.50it/s, resid=3.30E-03]
#
# LinearLeastSquares:  22%|██▏       | 22/100 [00:00<00:01, 40.50it/s, resid=3.12E-03]
#
# LinearLeastSquares:  23%|██▎       | 23/100 [00:00<00:01, 40.50it/s, resid=2.95E-03]
#
# LinearLeastSquares:  24%|██▍       | 24/100 [00:00<00:01, 40.92it/s, resid=2.95E-03]
#
# LinearLeastSquares:  24%|██▍       | 24/100 [00:00<00:01, 40.92it/s, resid=2.80E-03]
#
# LinearLeastSquares:  25%|██▌       | 25/100 [00:00<00:01, 40.92it/s, resid=2.67E-03]
#
# LinearLeastSquares:  26%|██▌       | 26/100 [00:00<00:01, 40.92it/s, resid=2.54E-03]
#
# LinearLeastSquares:  27%|██▋       | 27/100 [00:00<00:01, 40.92it/s, resid=2.43E-03]
#
# LinearLeastSquares:  28%|██▊       | 28/100 [00:00<00:01, 40.92it/s, resid=2.32E-03]
#
# LinearLeastSquares:  29%|██▉       | 29/100 [00:00<00:01, 40.84it/s, resid=2.32E-03]
#
# LinearLeastSquares:  29%|██▉       | 29/100 [00:00<00:01, 40.84it/s, resid=2.22E-03]
#
# LinearLeastSquares:  30%|███       | 30/100 [00:00<00:01, 40.84it/s, resid=2.13E-03]
#
# LinearLeastSquares:  31%|███       | 31/100 [00:00<00:01, 40.84it/s, resid=2.04E-03]
#
# LinearLeastSquares:  32%|███▏      | 32/100 [00:00<00:01, 40.84it/s, resid=1.96E-03]
#
# LinearLeastSquares:  33%|███▎      | 33/100 [00:00<00:01, 39.82it/s, resid=1.96E-03]
#
# LinearLeastSquares:  33%|███▎      | 33/100 [00:00<00:01, 39.82it/s, resid=1.88E-03]
#
# LinearLeastSquares:  34%|███▍      | 34/100 [00:00<00:01, 39.82it/s, resid=1.81E-03]
#
# LinearLeastSquares:  35%|███▌      | 35/100 [00:00<00:01, 39.82it/s, resid=1.74E-03]
#
# LinearLeastSquares:  36%|███▌      | 36/100 [00:00<00:01, 39.82it/s, resid=1.67E-03]
#
# LinearLeastSquares:  37%|███▋      | 37/100 [00:00<00:01, 39.55it/s, resid=1.67E-03]
#
# LinearLeastSquares:  37%|███▋      | 37/100 [00:00<00:01, 39.55it/s, resid=1.61E-03]
#
# LinearLeastSquares:  38%|███▊      | 38/100 [00:00<00:01, 39.55it/s, resid=1.55E-03]
#
# LinearLeastSquares:  39%|███▉      | 39/100 [00:00<00:01, 39.55it/s, resid=1.49E-03]
#
# LinearLeastSquares:  40%|████      | 40/100 [00:01<00:01, 39.55it/s, resid=1.44E-03]
#
# LinearLeastSquares:  41%|████      | 41/100 [00:01<00:01, 39.55it/s, resid=1.39E-03]
#
# LinearLeastSquares:  42%|████▏     | 42/100 [00:01<00:01, 40.05it/s, resid=1.39E-03]
#
# LinearLeastSquares:  42%|████▏     | 42/100 [00:01<00:01, 40.05it/s, resid=1.34E-03]
#
# LinearLeastSquares:  43%|████▎     | 43/100 [00:01<00:01, 40.05it/s, resid=1.29E-03]
#
# LinearLeastSquares:  44%|████▍     | 44/100 [00:01<00:01, 40.05it/s, resid=1.25E-03]
#
# LinearLeastSquares:  45%|████▌     | 45/100 [00:01<00:01, 40.05it/s, resid=1.20E-03]
#
# LinearLeastSquares:  46%|████▌     | 46/100 [00:01<00:01, 40.05it/s, resid=1.16E-03]
#
# LinearLeastSquares:  47%|████▋     | 47/100 [00:01<00:01, 40.36it/s, resid=1.16E-03]
#
# LinearLeastSquares:  47%|████▋     | 47/100 [00:01<00:01, 40.36it/s, resid=1.12E-03]
#
# LinearLeastSquares:  48%|████▊     | 48/100 [00:01<00:01, 40.36it/s, resid=1.09E-03]
#
# LinearLeastSquares:  49%|████▉     | 49/100 [00:01<00:01, 40.36it/s, resid=1.05E-03]
#
# LinearLeastSquares:  50%|█████     | 50/100 [00:01<00:01, 40.36it/s, resid=1.01E-03]
#
# LinearLeastSquares:  51%|█████     | 51/100 [00:01<00:01, 40.08it/s, resid=1.01E-03]
#
# LinearLeastSquares:  51%|█████     | 51/100 [00:01<00:01, 40.08it/s, resid=9.80E-04]
#
# LinearLeastSquares:  52%|█████▏    | 52/100 [00:01<00:01, 40.08it/s, resid=9.48E-04]
#
# LinearLeastSquares:  53%|█████▎    | 53/100 [00:01<00:01, 40.08it/s, resid=9.17E-04]
#
# LinearLeastSquares:  54%|█████▍    | 54/100 [00:01<00:01, 40.08it/s, resid=8.88E-04]
#
# LinearLeastSquares:  55%|█████▌    | 55/100 [00:01<00:01, 39.96it/s, resid=8.88E-04]
#
# LinearLeastSquares:  55%|█████▌    | 55/100 [00:01<00:01, 39.96it/s, resid=8.59E-04]
#
# LinearLeastSquares:  56%|█████▌    | 56/100 [00:01<00:01, 39.96it/s, resid=8.32E-04]
#
# LinearLeastSquares:  57%|█████▋    | 57/100 [00:01<00:01, 39.96it/s, resid=8.05E-04]
#
# LinearLeastSquares:  58%|█████▊    | 58/100 [00:01<00:01, 39.96it/s, resid=7.80E-04]
#
# LinearLeastSquares:  59%|█████▉    | 59/100 [00:01<00:01, 39.96it/s, resid=7.56E-04]
#
# LinearLeastSquares:  60%|██████    | 60/100 [00:01<00:01, 39.77it/s, resid=7.56E-04]
#
# LinearLeastSquares:  60%|██████    | 60/100 [00:01<00:01, 39.77it/s, resid=7.32E-04]
#
# LinearLeastSquares:  61%|██████    | 61/100 [00:01<00:00, 39.77it/s, resid=7.10E-04]
#
# LinearLeastSquares:  62%|██████▏   | 62/100 [00:01<00:00, 39.77it/s, resid=6.88E-04]
#
# LinearLeastSquares:  63%|██████▎   | 63/100 [00:01<00:00, 39.77it/s, resid=6.67E-04]
#
# LinearLeastSquares:  64%|██████▍   | 64/100 [00:01<00:00, 39.77it/s, resid=6.47E-04]
#
# LinearLeastSquares:  65%|██████▌   | 65/100 [00:01<00:00, 40.74it/s, resid=6.47E-04]
#
# LinearLeastSquares:  65%|██████▌   | 65/100 [00:01<00:00, 40.74it/s, resid=6.27E-04]
#
# LinearLeastSquares:  66%|██████▌   | 66/100 [00:01<00:00, 40.74it/s, resid=6.08E-04]
#
# LinearLeastSquares:  67%|██████▋   | 67/100 [00:01<00:00, 40.74it/s, resid=5.90E-04]
#
# LinearLeastSquares:  68%|██████▊   | 68/100 [00:01<00:00, 40.74it/s, resid=5.73E-04]
#
# LinearLeastSquares:  69%|██████▉   | 69/100 [00:01<00:00, 40.74it/s, resid=5.56E-04]
#
# LinearLeastSquares:  70%|███████   | 70/100 [00:01<00:00, 40.84it/s, resid=5.56E-04]
#
# LinearLeastSquares:  70%|███████   | 70/100 [00:01<00:00, 40.84it/s, resid=5.40E-04]
#
# LinearLeastSquares:  71%|███████   | 71/100 [00:01<00:00, 40.84it/s, resid=5.24E-04]
#
# LinearLeastSquares:  72%|███████▏  | 72/100 [00:01<00:00, 40.84it/s, resid=5.09E-04]
#
# LinearLeastSquares:  73%|███████▎  | 73/100 [00:01<00:00, 40.84it/s, resid=4.94E-04]
#
# LinearLeastSquares:  74%|███████▍  | 74/100 [00:01<00:00, 40.84it/s, resid=4.80E-04]
#
# LinearLeastSquares:  75%|███████▌  | 75/100 [00:01<00:00, 40.49it/s, resid=4.80E-04]
#
# LinearLeastSquares:  75%|███████▌  | 75/100 [00:01<00:00, 40.49it/s, resid=4.67E-04]
#
# LinearLeastSquares:  76%|███████▌  | 76/100 [00:01<00:00, 40.49it/s, resid=4.53E-04]
#
# LinearLeastSquares:  77%|███████▋  | 77/100 [00:01<00:00, 40.49it/s, resid=4.41E-04]
#
# LinearLeastSquares:  78%|███████▊  | 78/100 [00:01<00:00, 40.49it/s, resid=4.28E-04]
#
# LinearLeastSquares:  79%|███████▉  | 79/100 [00:01<00:00, 40.49it/s, resid=4.17E-04]
#
# LinearLeastSquares:  80%|████████  | 80/100 [00:01<00:00, 40.63it/s, resid=4.17E-04]
#
# LinearLeastSquares:  80%|████████  | 80/100 [00:02<00:00, 40.63it/s, resid=4.05E-04]
#
# LinearLeastSquares:  81%|████████  | 81/100 [00:02<00:00, 40.63it/s, resid=3.94E-04]
#
# LinearLeastSquares:  82%|████████▏ | 82/100 [00:02<00:00, 40.63it/s, resid=3.83E-04]
#
# LinearLeastSquares:  83%|████████▎ | 83/100 [00:02<00:00, 40.63it/s, resid=3.73E-04]
#
# LinearLeastSquares:  84%|████████▍ | 84/100 [00:02<00:00, 40.63it/s, resid=3.63E-04]
#
# LinearLeastSquares:  85%|████████▌ | 85/100 [00:02<00:00, 41.23it/s, resid=3.63E-04]
#
# LinearLeastSquares:  85%|████████▌ | 85/100 [00:02<00:00, 41.23it/s, resid=3.53E-04]
#
# LinearLeastSquares:  86%|████████▌ | 86/100 [00:02<00:00, 41.23it/s, resid=3.44E-04]
#
# LinearLeastSquares:  87%|████████▋ | 87/100 [00:02<00:00, 41.23it/s, resid=3.35E-04]
#
# LinearLeastSquares:  88%|████████▊ | 88/100 [00:02<00:00, 41.23it/s, resid=3.26E-04]
#
# LinearLeastSquares:  89%|████████▉ | 89/100 [00:02<00:00, 41.23it/s, resid=3.17E-04]
#
# LinearLeastSquares:  90%|█████████ | 90/100 [00:02<00:00, 41.01it/s, resid=3.17E-04]
#
# LinearLeastSquares:  90%|█████████ | 90/100 [00:02<00:00, 41.01it/s, resid=3.09E-04]
#
# LinearLeastSquares:  91%|█████████ | 91/100 [00:02<00:00, 41.01it/s, resid=3.01E-04]
#
# LinearLeastSquares:  92%|█████████▏| 92/100 [00:02<00:00, 41.01it/s, resid=2.93E-04]
#
# LinearLeastSquares:  93%|█████████▎| 93/100 [00:02<00:00, 41.01it/s, resid=2.86E-04]
#
# LinearLeastSquares:  94%|█████████▍| 94/100 [00:02<00:00, 41.01it/s, resid=2.79E-04]
#
# LinearLeastSquares:  95%|█████████▌| 95/100 [00:02<00:00, 38.85it/s, resid=2.79E-04]
#
# LinearLeastSquares:  95%|█████████▌| 95/100 [00:02<00:00, 38.85it/s, resid=2.72E-04]
#
# LinearLeastSquares:  96%|█████████▌| 96/100 [00:02<00:00, 38.85it/s, resid=2.65E-04]
#
# LinearLeastSquares:  97%|█████████▋| 97/100 [00:02<00:00, 38.85it/s, resid=2.58E-04]
#
# LinearLeastSquares:  98%|█████████▊| 98/100 [00:02<00:00, 38.85it/s, resid=2.52E-04]
#
# LinearLeastSquares:  99%|█████████▉| 99/100 [00:02<00:00, 38.85it/s, resid=2.46E-04]
#
# LinearLeastSquares: 100%|██████████| 100/100 [00:02<00:00, 39.67it/s, resid=2.46E-04]
#
# MaxEig:   0%|          | 0/30 [00:00<?, ?it/s]
#
# MaxEig:   0%|          | 0/30 [00:00<?, ?it/s, max_eig=2.84E+02]
#
# MaxEig:   3%|▎         | 1/30 [00:00<00:01, 20.06it/s, max_eig=4.16E+01]
#
# MaxEig:   7%|▋         | 2/30 [00:00<00:00, 28.28it/s, max_eig=1.08E+02]
#
# MaxEig:  10%|█         | 3/30 [00:00<00:00, 32.54it/s, max_eig=1.44E+02]
#
# MaxEig:  13%|█▎        | 4/30 [00:00<00:00, 35.30it/s, max_eig=1.55E+02]
#
# MaxEig:  17%|█▋        | 5/30 [00:00<00:00, 43.59it/s, max_eig=1.55E+02]
#
# MaxEig:  17%|█▋        | 5/30 [00:00<00:00, 43.59it/s, max_eig=1.57E+02]
#
# MaxEig:  20%|██        | 6/30 [00:00<00:00, 43.59it/s, max_eig=1.57E+02]
#
# MaxEig:  23%|██▎       | 7/30 [00:00<00:00, 43.59it/s, max_eig=1.57E+02]
# 1
# MaxEig:  27%|██▋       | 8/30 [00:00<00:00, 43.59it/s, max_eig=1.57E+02]
#
# MaxEig:  30%|███       | 9/30 [00:00<00:00, 42.16it/s, max_eig=1.57E+02]
#
# MaxEig:  30%|███       | 9/30 [00:00<00:00, 42.16it/s, max_eig=1.57E+02]
#
# MaxEig:  33%|███▎      | 10/30 [00:00<00:00, 42.16it/s, max_eig=1.57E+02]
#
# MaxEig:  37%|███▋      | 11/30 [00:00<00:00, 42.16it/s, max_eig=1.57E+02]
#
# MaxEig:  40%|████      | 12/30 [00:00<00:00, 42.16it/s, max_eig=1.57E+02]
#
# MaxEig:  43%|████▎     | 13/30 [00:00<00:00, 42.16it/s, max_eig=1.57E+02]
#
# MaxEig:  47%|████▋     | 14/30 [00:00<00:00, 42.92it/s, max_eig=1.57E+02]
#
# MaxEig:  47%|████▋     | 14/30 [00:00<00:00, 42.92it/s, max_eig=1.57E+02]
#
# MaxEig:  50%|█████     | 15/30 [00:00<00:00, 42.92it/s, max_eig=1.57E+02]
#
# MaxEig:  53%|█████▎    | 16/30 [00:00<00:00, 42.92it/s, max_eig=1.57E+02]
#
# MaxEig:  57%|█████▋    | 17/30 [00:00<00:00, 42.92it/s, max_eig=1.57E+02]
#
# MaxEig:  60%|██████    | 18/30 [00:00<00:00, 42.92it/s, max_eig=1.57E+02]
#
# MaxEig:  63%|██████▎   | 19/30 [00:00<00:00, 43.12it/s, max_eig=1.57E+02]
#
# MaxEig:  63%|██████▎   | 19/30 [00:00<00:00, 43.12it/s, max_eig=1.57E+02]
#
# MaxEig:  67%|██████▋   | 20/30 [00:00<00:00, 43.12it/s, max_eig=1.57E+02]
#
# MaxEig:  70%|███████   | 21/30 [00:00<00:00, 43.12it/s, max_eig=1.57E+02]
#
# MaxEig:  73%|███████▎  | 22/30 [00:00<00:00, 43.12it/s, max_eig=1.57E+02]
#
# MaxEig:  77%|███████▋  | 23/30 [00:00<00:00, 43.12it/s, max_eig=1.57E+02]
#
# MaxEig:  80%|████████  | 24/30 [00:00<00:00, 42.65it/s, max_eig=1.57E+02]
#
# MaxEig:  80%|████████  | 24/30 [00:00<00:00, 42.65it/s, max_eig=1.57E+02]
#
# MaxEig:  83%|████████▎ | 25/30 [00:00<00:00, 42.65it/s, max_eig=1.57E+02]
#
# MaxEig:  87%|████████▋ | 26/30 [00:00<00:00, 42.65it/s, max_eig=1.57E+02]
#
# MaxEig:  90%|█████████ | 27/30 [00:00<00:00, 42.65it/s, max_eig=1.57E+02]
#
# MaxEig:  93%|█████████▎| 28/30 [00:00<00:00, 42.65it/s, max_eig=1.57E+02]
#
# MaxEig:  97%|█████████▋| 29/30 [00:00<00:00, 43.27it/s, max_eig=1.57E+02]
#
# MaxEig:  97%|█████████▋| 29/30 [00:00<00:00, 43.27it/s, max_eig=1.57E+02]
#
# MaxEig: 100%|██████████| 30/30 [00:00<00:00, 42.83it/s, max_eig=1.57E+02]
#
# LinearLeastSquares:   0%|          | 0/100 [00:00<?, ?it/s]
#
# LinearLeastSquares:   0%|          | 0/100 [00:00<?, ?it/s, resid=7.81E-01]
#
# LinearLeastSquares:   1%|          | 1/100 [00:00<00:04, 20.46it/s, resid=2.05E-01]
#
# LinearLeastSquares:   2%|▏         | 2/100 [00:00<00:03, 27.59it/s, resid=1.34E-01]
#
# LinearLeastSquares:   3%|▎         | 3/100 [00:00<00:03, 31.26it/s, resid=8.64E-02]
#
# LinearLeastSquares:   4%|▍         | 4/100 [00:00<00:02, 33.47it/s, resid=5.70E-02]
#
# LinearLeastSquares:   5%|▌         | 5/100 [00:00<00:02, 41.38it/s, resid=5.70E-02]
#
# LinearLeastSquares:   5%|▌         | 5/100 [00:00<00:02, 41.38it/s, resid=3.88E-02]
#
# LinearLeastSquares:   6%|▌         | 6/100 [00:00<00:02, 41.38it/s, resid=2.76E-02]
#
# LinearLeastSquares:   7%|▋         | 7/100 [00:00<00:02, 41.38it/s, resid=2.04E-02]
#
# LinearLeastSquares:   8%|▊         | 8/100 [00:00<00:02, 41.38it/s, resid=1.58E-02]
#
# LinearLeastSquares:   9%|▉         | 9/100 [00:00<00:02, 41.38it/s, resid=1.27E-02]
#
# LinearLeastSquares:  10%|█         | 10/100 [00:00<00:02, 41.63it/s, resid=1.27E-02]
#
# LinearLeastSquares:  10%|█         | 10/100 [00:00<00:02, 41.63it/s, resid=1.04E-02]
#
# LinearLeastSquares:  11%|█         | 11/100 [00:00<00:02, 41.63it/s, resid=8.84E-03]
#
# LinearLeastSquares:  12%|█▏        | 12/100 [00:00<00:02, 41.63it/s, resid=7.63E-03]
#
# LinearLeastSquares:  13%|█▎        | 13/100 [00:00<00:02, 41.63it/s, resid=6.70E-03]
#
# LinearLeastSquares:  14%|█▍        | 14/100 [00:00<00:02, 41.07it/s, resid=6.70E-03]
#
# LinearLeastSquares:  14%|█▍        | 14/100 [00:00<00:02, 41.07it/s, resid=5.97E-03]
#
# LinearLeastSquares:  15%|█▌        | 15/100 [00:00<00:02, 41.07it/s, resid=5.39E-03]
#
# LinearLeastSquares:  16%|█▌        | 16/100 [00:00<00:02, 41.07it/s, resid=4.90E-03]
#
# LinearLeastSquares:  17%|█▋        | 17/100 [00:00<00:02, 41.07it/s, resid=4.50E-03]
#
# LinearLeastSquares:  18%|█▊        | 18/100 [00:00<00:01, 41.07it/s, resid=4.16E-03]
#
# LinearLeastSquares:  19%|█▉        | 19/100 [00:00<00:01, 41.37it/s, resid=4.16E-03]
#
# LinearLeastSquares:  19%|█▉        | 19/100 [00:00<00:01, 41.37it/s, resid=3.87E-03]
#
# LinearLeastSquares:  20%|██        | 20/100 [00:00<00:01, 41.37it/s, resid=3.62E-03]
#
# LinearLeastSquares:  21%|██        | 21/100 [00:00<00:01, 41.37it/s, resid=3.40E-03]
#
# LinearLeastSquares:  22%|██▏       | 22/100 [00:00<00:01, 41.37it/s, resid=3.21E-03]
#
# LinearLeastSquares:  23%|██▎       | 23/100 [00:00<00:01, 40.47it/s, resid=3.21E-03]
#
# LinearLeastSquares:  23%|██▎       | 23/100 [00:00<00:01, 40.47it/s, resid=3.03E-03]
#
# LinearLeastSquares:  24%|██▍       | 24/100 [00:00<00:01, 40.47it/s, resid=2.88E-03]
#
# LinearLeastSquares:  25%|██▌       | 25/100 [00:00<00:01, 40.47it/s, resid=2.73E-03]
#
# LinearLeastSquares:  26%|██▌       | 26/100 [00:00<00:01, 40.47it/s, resid=2.60E-03]
#
# LinearLeastSquares:  27%|██▋       | 27/100 [00:00<00:01, 40.47it/s, resid=2.48E-03]
#
# LinearLeastSquares:  28%|██▊       | 28/100 [00:00<00:01, 40.97it/s, resid=2.48E-03]
#
# LinearLeastSquares:  28%|██▊       | 28/100 [00:00<00:01, 40.97it/s, resid=2.37E-03]
#
# LinearLeastSquares:  29%|██▉       | 29/100 [00:00<00:01, 40.97it/s, resid=2.27E-03]
#
# LinearLeastSquares:  30%|███       | 30/100 [00:00<00:01, 40.97it/s, resid=2.17E-03]
#
# LinearLeastSquares:  31%|███       | 31/100 [00:00<00:01, 40.97it/s, resid=2.08E-03]
#
# LinearLeastSquares:  32%|███▏      | 32/100 [00:00<00:01, 40.97it/s, resid=2.00E-03]
#
# LinearLeastSquares:  33%|███▎      | 33/100 [00:00<00:01, 40.96it/s, resid=2.00E-03]
#
# LinearLeastSquares:  33%|███▎      | 33/100 [00:00<00:01, 40.96it/s, resid=1.92E-03]
#
# LinearLeastSquares:  34%|███▍      | 34/100 [00:00<00:01, 40.96it/s, resid=1.84E-03]
#
# LinearLeastSquares:  35%|███▌      | 35/100 [00:00<00:01, 40.96it/s, resid=1.77E-03]
#
# LinearLeastSquares:  36%|███▌      | 36/100 [00:00<00:01, 40.96it/s, resid=1.70E-03]
#
# LinearLeastSquares:  37%|███▋      | 37/100 [00:00<00:01, 40.96it/s, resid=1.64E-03]
#
# LinearLeastSquares:  38%|███▊      | 38/100 [00:00<00:01, 39.97it/s, resid=1.64E-03]
#
# LinearLeastSquares:  38%|███▊      | 38/100 [00:00<00:01, 39.97it/s, resid=1.58E-03]
#
# LinearLeastSquares:  39%|███▉      | 39/100 [00:01<00:01, 39.97it/s, resid=1.52E-03]
#
# LinearLeastSquares:  40%|████      | 40/100 [00:01<00:01, 39.97it/s, resid=1.47E-03]
#
# LinearLeastSquares:  41%|████      | 41/100 [00:01<00:01, 39.97it/s, resid=1.41E-03]
#
# LinearLeastSquares:  42%|████▏     | 42/100 [00:01<00:01, 37.30it/s, resid=1.41E-03]
#
# LinearLeastSquares:  42%|████▏     | 42/100 [00:01<00:01, 37.30it/s, resid=1.36E-03]
#
# LinearLeastSquares:  43%|████▎     | 43/100 [00:01<00:01, 37.30it/s, resid=1.32E-03]
#
# LinearLeastSquares:  44%|████▍     | 44/100 [00:01<00:01, 37.30it/s, resid=1.27E-03]
#
# LinearLeastSquares:  45%|████▌     | 45/100 [00:01<00:01, 37.30it/s, resid=1.23E-03]
#
# LinearLeastSquares:  46%|████▌     | 46/100 [00:01<00:01, 37.30it/s, resid=1.18E-03]
#
# LinearLeastSquares:  47%|████▋     | 47/100 [00:01<00:01, 38.32it/s, resid=1.18E-03]
#
# LinearLeastSquares:  47%|████▋     | 47/100 [00:01<00:01, 38.32it/s, resid=1.14E-03]
#
# LinearLeastSquares:  48%|████▊     | 48/100 [00:01<00:01, 38.32it/s, resid=1.11E-03]
#
# LinearLeastSquares:  49%|████▉     | 49/100 [00:01<00:01, 38.32it/s, resid=1.07E-03]
#
# LinearLeastSquares:  50%|█████     | 50/100 [00:01<00:01, 38.32it/s, resid=1.03E-03]
#
# LinearLeastSquares:  51%|█████     | 51/100 [00:01<00:01, 38.32it/s, resid=1.00E-03]
#
# LinearLeastSquares:  52%|█████▏    | 52/100 [00:01<00:01, 39.55it/s, resid=1.00E-03]
#
# LinearLeastSquares:  52%|█████▏    | 52/100 [00:01<00:01, 39.55it/s, resid=9.68E-04]
#
# LinearLeastSquares:  53%|█████▎    | 53/100 [00:01<00:01, 39.55it/s, resid=9.36E-04]
#
# LinearLeastSquares:  54%|█████▍    | 54/100 [00:01<00:01, 39.55it/s, resid=9.06E-04]
#
# LinearLeastSquares:  55%|█████▌    | 55/100 [00:01<00:01, 39.55it/s, resid=8.78E-04]
#
# LinearLeastSquares:  56%|█████▌    | 56/100 [00:01<00:01, 39.55it/s, resid=8.50E-04]
#
# LinearLeastSquares:  57%|█████▋    | 57/100 [00:01<00:01, 40.36it/s, resid=8.50E-04]
#
# LinearLeastSquares:  57%|█████▋    | 57/100 [00:01<00:01, 40.36it/s, resid=8.23E-04]
#
# LinearLeastSquares:  58%|█████▊    | 58/100 [00:01<00:01, 40.36it/s, resid=7.98E-04]
#
# LinearLeastSquares:  59%|█████▉    | 59/100 [00:01<00:01, 40.36it/s, resid=7.73E-04]
#
# LinearLeastSquares:  60%|██████    | 60/100 [00:01<00:00, 40.36it/s, resid=7.49E-04]
#
# LinearLeastSquares:  61%|██████    | 61/100 [00:01<00:00, 40.36it/s, resid=7.27E-04]
#
# LinearLeastSquares:  62%|██████▏   | 62/100 [00:01<00:00, 40.77it/s, resid=7.27E-04]
#
# LinearLeastSquares:  62%|██████▏   | 62/100 [00:01<00:00, 40.77it/s, resid=7.05E-04]
#
# LinearLeastSquares:  63%|██████▎   | 63/100 [00:01<00:00, 40.77it/s, resid=6.83E-04]
#
# LinearLeastSquares:  64%|██████▍   | 64/100 [00:01<00:00, 40.77it/s, resid=6.63E-04]
#
# LinearLeastSquares:  65%|██████▌   | 65/100 [00:01<00:00, 40.77it/s, resid=6.43E-04]
#
# LinearLeastSquares:  66%|██████▌   | 66/100 [00:01<00:00, 40.77it/s, resid=6.24E-04]
#
# LinearLeastSquares:  67%|██████▋   | 67/100 [00:01<00:00, 41.00it/s, resid=6.24E-04]
#
# LinearLeastSquares:  67%|██████▋   | 67/100 [00:01<00:00, 41.00it/s, resid=6.06E-04]
#
# LinearLeastSquares:  68%|██████▊   | 68/100 [00:01<00:00, 41.00it/s, resid=5.89E-04]
#
# LinearLeastSquares:  69%|██████▉   | 69/100 [00:01<00:00, 41.00it/s, resid=5.72E-04]
#
# LinearLeastSquares:  70%|███████   | 70/100 [00:01<00:00, 41.00it/s, resid=5.55E-04]
#
# LinearLeastSquares:  71%|███████   | 71/100 [00:01<00:00, 41.00it/s, resid=5.39E-04]
#
# LinearLeastSquares:  72%|███████▏  | 72/100 [00:01<00:00, 41.34it/s, resid=5.39E-04]
#
# LinearLeastSquares:  72%|███████▏  | 72/100 [00:01<00:00, 41.34it/s, resid=5.24E-04]
#
# LinearLeastSquares:  73%|███████▎  | 73/100 [00:01<00:00, 41.34it/s, resid=5.09E-04]
#
# LinearLeastSquares:  74%|███████▍  | 74/100 [00:01<00:00, 41.34it/s, resid=4.95E-04]
#
# LinearLeastSquares:  75%|███████▌  | 75/100 [00:01<00:00, 41.34it/s, resid=4.81E-04]
#
# LinearLeastSquares:  76%|███████▌  | 76/100 [00:01<00:00, 41.34it/s, resid=4.68E-04]
#
# LinearLeastSquares:  77%|███████▋  | 77/100 [00:01<00:00, 40.77it/s, resid=4.68E-04]
#
# LinearLeastSquares:  77%|███████▋  | 77/100 [00:01<00:00, 40.77it/s, resid=4.55E-04]
#
# LinearLeastSquares:  78%|███████▊  | 78/100 [00:01<00:00, 40.77it/s, resid=4.43E-04]
#
# LinearLeastSquares:  79%|███████▉  | 79/100 [00:01<00:00, 40.77it/s, resid=4.31E-04]
#
# LinearLeastSquares:  80%|████████  | 80/100 [00:01<00:00, 40.77it/s, resid=4.19E-04]
#
# LinearLeastSquares:  81%|████████  | 81/100 [00:02<00:00, 40.77it/s, resid=4.08E-04]
#
# LinearLeastSquares:  82%|████████▏ | 82/100 [00:02<00:00, 40.88it/s, resid=4.08E-04]
#
# LinearLeastSquares:  82%|████████▏ | 82/100 [00:02<00:00, 40.88it/s, resid=3.98E-04]
#
# LinearLeastSquares:  83%|████████▎ | 83/100 [00:02<00:00, 40.88it/s, resid=3.87E-04]
#
# LinearLeastSquares:  84%|████████▍ | 84/100 [00:02<00:00, 40.88it/s, resid=3.77E-04]
#
# LinearLeastSquares:  85%|████████▌ | 85/100 [00:02<00:00, 40.88it/s, resid=3.67E-04]
#
# LinearLeastSquares:  86%|████████▌ | 86/100 [00:02<00:00, 40.88it/s, resid=3.58E-04]
#
# LinearLeastSquares:  87%|████████▋ | 87/100 [00:02<00:00, 41.52it/s, resid=3.58E-04]
#
# LinearLeastSquares:  87%|████████▋ | 87/100 [00:02<00:00, 41.52it/s, resid=3.49E-04]
#
# LinearLeastSquares:  88%|████████▊ | 88/100 [00:02<00:00, 41.52it/s, resid=3.40E-04]
#
# LinearLeastSquares:  89%|████████▉ | 89/100 [00:02<00:00, 41.52it/s, resid=3.31E-04]
#
# LinearLeastSquares:  90%|█████████ | 90/100 [00:02<00:00, 41.52it/s, resid=3.23E-04]
#
# LinearLeastSquares:  91%|█████████ | 91/100 [00:02<00:00, 41.52it/s, resid=3.15E-04]
#
# LinearLeastSquares:  92%|█████████▏| 92/100 [00:02<00:00, 39.94it/s, resid=3.15E-04]
#
# LinearLeastSquares:  92%|█████████▏| 92/100 [00:02<00:00, 39.94it/s, resid=3.07E-04]
#
# LinearLeastSquares:  93%|█████████▎| 93/100 [00:02<00:00, 39.94it/s, resid=2.99E-04]
#
# LinearLeastSquares:  94%|█████████▍| 94/100 [00:02<00:00, 39.94it/s, resid=2.92E-04]
#
# LinearLeastSquares:  95%|█████████▌| 95/100 [00:02<00:00, 39.94it/s, resid=2.85E-04]
#
# LinearLeastSquares:  96%|█████████▌| 96/100 [00:02<00:00, 39.94it/s, resid=2.78E-04]
#
# LinearLeastSquares:  97%|█████████▋| 97/100 [00:02<00:00, 39.52it/s, resid=2.78E-04]
#
# LinearLeastSquares:  97%|█████████▋| 97/100 [00:02<00:00, 39.52it/s, resid=2.72E-04]
#
# LinearLeastSquares:  98%|█████████▊| 98/100 [00:02<00:00, 39.52it/s, resid=2.65E-04]
#
# LinearLeastSquares:  99%|█████████▉| 99/100 [00:02<00:00, 39.52it/s, resid=2.59E-04]
#
# LinearLeastSquares: 100%|██████████| 100/100 [00:02<00:00, 40.31it/s, resid=2.59E-04]
#
# MaxEig:   0%|          | 0/30 [00:00<?, ?it/s]
#
# MaxEig:   0%|          | 0/30 [00:00<?, ?it/s, max_eig=3.33E+02]
#
# MaxEig:   3%|▎         | 1/30 [00:00<00:01, 20.60it/s, max_eig=9.48E+01]
#
# MaxEig:   7%|▋         | 2/30 [00:00<00:00, 28.15it/s, max_eig=1.52E+02]
#
# MaxEig:  10%|█         | 3/30 [00:00<00:00, 32.13it/s, max_eig=1.57E+02]
#
# MaxEig:  13%|█▎        | 4/30 [00:00<00:00, 35.01it/s, max_eig=1.57E+02]
#
# MaxEig:  17%|█▋        | 5/30 [00:00<00:00, 43.21it/s, max_eig=1.57E+02]
#
# MaxEig:  17%|█▋        | 5/30 [00:00<00:00, 43.21it/s, max_eig=1.57E+02]
#
# MaxEig:  20%|██        | 6/30 [00:00<00:00, 43.21it/s, max_eig=1.57E+02]
#
# MaxEig:  23%|██▎       | 7/30 [00:00<00:00, 43.21it/s, max_eig=1.57E+02]
# 2
# MaxEig:  27%|██▋       | 8/30 [00:00<00:00, 43.21it/s, max_eig=1.57E+02]
#
# MaxEig:  30%|███       | 9/30 [00:00<00:00, 43.21it/s, max_eig=1.57E+02]
#
# MaxEig:  33%|███▎      | 10/30 [00:00<00:00, 43.80it/s, max_eig=1.57E+02]
#
# MaxEig:  33%|███▎      | 10/30 [00:00<00:00, 43.80it/s, max_eig=1.57E+02]
#
# MaxEig:  37%|███▋      | 11/30 [00:00<00:00, 43.80it/s, max_eig=1.57E+02]
#
# MaxEig:  40%|████      | 12/30 [00:00<00:00, 43.80it/s, max_eig=1.57E+02]
#
# MaxEig:  43%|████▎     | 13/30 [00:00<00:00, 43.80it/s, max_eig=1.57E+02]
#
# MaxEig:  47%|████▋     | 14/30 [00:00<00:00, 43.80it/s, max_eig=1.57E+02]
#
# MaxEig:  50%|█████     | 15/30 [00:00<00:00, 44.08it/s, max_eig=1.57E+02]
#
# MaxEig:  50%|█████     | 15/30 [00:00<00:00, 44.08it/s, max_eig=1.57E+02]
#
# MaxEig:  53%|█████▎    | 16/30 [00:00<00:00, 44.08it/s, max_eig=1.57E+02]
#
# MaxEig:  57%|█████▋    | 17/30 [00:00<00:00, 44.08it/s, max_eig=1.57E+02]
#
# MaxEig:  60%|██████    | 18/30 [00:00<00:00, 44.08it/s, max_eig=1.57E+02]
#
# MaxEig:  63%|██████▎   | 19/30 [00:00<00:00, 44.08it/s, max_eig=1.57E+02]
#
# MaxEig:  67%|██████▋   | 20/30 [00:00<00:00, 44.28it/s, max_eig=1.57E+02]
#
# MaxEig:  67%|██████▋   | 20/30 [00:00<00:00, 44.28it/s, max_eig=1.57E+02]
#
# MaxEig:  70%|███████   | 21/30 [00:00<00:00, 44.28it/s, max_eig=1.57E+02]
#
# MaxEig:  73%|███████▎  | 22/30 [00:00<00:00, 44.28it/s, max_eig=1.57E+02]
#
# MaxEig:  77%|███████▋  | 23/30 [00:00<00:00, 44.28it/s, max_eig=1.57E+02]
#
# MaxEig:  80%|████████  | 24/30 [00:00<00:00, 41.68it/s, max_eig=1.57E+02]
#
# MaxEig:  80%|████████  | 24/30 [00:00<00:00, 41.68it/s, max_eig=1.57E+02]
#
# MaxEig:  83%|████████▎ | 25/30 [00:00<00:00, 41.68it/s, max_eig=1.57E+02]
#
# MaxEig:  87%|████████▋ | 26/30 [00:00<00:00, 41.68it/s, max_eig=1.57E+02]
#
# MaxEig:  90%|█████████ | 27/30 [00:00<00:00, 41.68it/s, max_eig=1.57E+02]
#
# MaxEig:  93%|█████████▎| 28/30 [00:00<00:00, 41.68it/s, max_eig=1.57E+02]
#
# MaxEig:  97%|█████████▋| 29/30 [00:00<00:00, 41.84it/s, max_eig=1.57E+02]
#
# MaxEig:  97%|█████████▋| 29/30 [00:00<00:00, 41.84it/s, max_eig=1.57E+02]
#
# MaxEig: 100%|██████████| 30/30 [00:00<00:00, 42.64it/s, max_eig=1.57E+02]
#
# LinearLeastSquares:   0%|          | 0/100 [00:00<?, ?it/s]
#
# LinearLeastSquares:   0%|          | 0/100 [00:00<?, ?it/s, resid=1.61E-01]
#
# LinearLeastSquares:   1%|          | 1/100 [00:00<00:04, 21.30it/s, resid=5.99E-02]
#
# LinearLeastSquares:   2%|▏         | 2/100 [00:00<00:03, 28.68it/s, resid=4.20E-02]
#
# LinearLeastSquares:   3%|▎         | 3/100 [00:00<00:02, 32.66it/s, resid=2.97E-02]
#
# LinearLeastSquares:   4%|▍         | 4/100 [00:00<00:02, 35.14it/s, resid=2.15E-02]
#
# LinearLeastSquares:   5%|▌         | 5/100 [00:00<00:02, 43.28it/s, resid=2.15E-02]
#
# LinearLeastSquares:   5%|▌         | 5/100 [00:00<00:02, 43.28it/s, resid=1.60E-02]
#
# LinearLeastSquares:   6%|▌         | 6/100 [00:00<00:02, 43.28it/s, resid=1.21E-02]
#
# LinearLeastSquares:   7%|▋         | 7/100 [00:00<00:02, 43.28it/s, resid=9.37E-03]
#
# LinearLeastSquares:   8%|▊         | 8/100 [00:00<00:02, 43.28it/s, resid=7.39E-03]
#
# LinearLeastSquares:   9%|▉         | 9/100 [00:00<00:02, 43.28it/s, resid=5.94E-03]
#
# LinearLeastSquares:  10%|█         | 10/100 [00:00<00:02, 43.19it/s, resid=5.94E-03]
#
# LinearLeastSquares:  10%|█         | 10/100 [00:00<00:02, 43.19it/s, resid=4.87E-03]
#
# LinearLeastSquares:  11%|█         | 11/100 [00:00<00:02, 43.19it/s, resid=4.07E-03]
#
# LinearLeastSquares:  12%|█▏        | 12/100 [00:00<00:02, 43.19it/s, resid=3.46E-03]
#
# LinearLeastSquares:  13%|█▎        | 13/100 [00:00<00:02, 43.19it/s, resid=2.99E-03]
#
# LinearLeastSquares:  14%|█▍        | 14/100 [00:00<00:01, 43.19it/s, resid=2.63E-03]
#
# LinearLeastSquares:  15%|█▌        | 15/100 [00:00<00:01, 43.00it/s, resid=2.63E-03]
#
# LinearLeastSquares:  15%|█▌        | 15/100 [00:00<00:01, 43.00it/s, resid=2.35E-03]
#
# LinearLeastSquares:  16%|█▌        | 16/100 [00:00<00:01, 43.00it/s, resid=2.13E-03]
#
# LinearLeastSquares:  17%|█▋        | 17/100 [00:00<00:01, 43.00it/s, resid=1.95E-03]
#
# LinearLeastSquares:  18%|█▊        | 18/100 [00:00<00:01, 43.00it/s, resid=1.79E-03]
#
# LinearLeastSquares:  19%|█▉        | 19/100 [00:00<00:02, 40.46it/s, resid=1.79E-03]
#
# LinearLeastSquares:  19%|█▉        | 19/100 [00:00<00:02, 40.46it/s, resid=1.67E-03]
#
# LinearLeastSquares:  20%|██        | 20/100 [00:00<00:01, 40.46it/s, resid=1.56E-03]
#
# LinearLeastSquares:  21%|██        | 21/100 [00:00<00:01, 40.46it/s, resid=1.47E-03]
#
# LinearLeastSquares:  22%|██▏       | 22/100 [00:00<00:01, 40.46it/s, resid=1.39E-03]
#
# LinearLeastSquares:  23%|██▎       | 23/100 [00:00<00:01, 40.46it/s, resid=1.32E-03]
#
# LinearLeastSquares:  24%|██▍       | 24/100 [00:00<00:01, 40.88it/s, resid=1.32E-03]
#
# LinearLeastSquares:  24%|██▍       | 24/100 [00:00<00:01, 40.88it/s, resid=1.25E-03]
#
# LinearLeastSquares:  25%|██▌       | 25/100 [00:00<00:01, 40.88it/s, resid=1.19E-03]
#
# LinearLeastSquares:  26%|██▌       | 26/100 [00:00<00:01, 40.88it/s, resid=1.14E-03]
#
# LinearLeastSquares:  27%|██▋       | 27/100 [00:00<00:01, 40.88it/s, resid=1.09E-03]
#
# LinearLeastSquares:  28%|██▊       | 28/100 [00:00<00:01, 40.88it/s, resid=1.04E-03]
#
# LinearLeastSquares:  29%|██▉       | 29/100 [00:00<00:01, 41.39it/s, resid=1.04E-03]
#
# LinearLeastSquares:  29%|██▉       | 29/100 [00:00<00:01, 41.39it/s, resid=9.98E-04]
#
# LinearLeastSquares:  30%|███       | 30/100 [00:00<00:01, 41.39it/s, resid=9.57E-04]
#
# LinearLeastSquares:  31%|███       | 31/100 [00:00<00:01, 41.39it/s, resid=9.19E-04]
#
# LinearLeastSquares:  32%|███▏      | 32/100 [00:00<00:01, 41.39it/s, resid=8.83E-04]
#
# LinearLeastSquares:  33%|███▎      | 33/100 [00:00<00:01, 41.39it/s, resid=8.49E-04]
#
# LinearLeastSquares:  34%|███▍      | 34/100 [00:00<00:01, 41.95it/s, resid=8.49E-04]
#
# LinearLeastSquares:  34%|███▍      | 34/100 [00:00<00:01, 41.95it/s, resid=8.17E-04]
#
# LinearLeastSquares:  35%|███▌      | 35/100 [00:00<00:01, 41.95it/s, resid=7.87E-04]
#
# LinearLeastSquares:  36%|███▌      | 36/100 [00:00<00:01, 41.95it/s, resid=7.58E-04]
#
# LinearLeastSquares:  37%|███▋      | 37/100 [00:00<00:01, 41.95it/s, resid=7.30E-04]
#
# LinearLeastSquares:  38%|███▊      | 38/100 [00:00<00:01, 41.21it/s, resid=7.30E-04]
#
# LinearLeastSquares:  38%|███▊      | 38/100 [00:00<00:01, 41.21it/s, resid=7.04E-04]
#
# LinearLeastSquares:  39%|███▉      | 39/100 [00:00<00:01, 41.21it/s, resid=6.79E-04]
#
# LinearLeastSquares:  40%|████      | 40/100 [00:00<00:01, 41.21it/s, resid=6.55E-04]
#
# LinearLeastSquares:  41%|████      | 41/100 [00:01<00:01, 41.21it/s, resid=6.32E-04]
#
# LinearLeastSquares:  42%|████▏     | 42/100 [00:01<00:01, 41.21it/s, resid=6.10E-04]
#
# LinearLeastSquares:  43%|████▎     | 43/100 [00:01<00:01, 41.60it/s, resid=6.10E-04]
#
# LinearLeastSquares:  43%|████▎     | 43/100 [00:01<00:01, 41.60it/s, resid=5.89E-04]
#
# LinearLeastSquares:  44%|████▍     | 44/100 [00:01<00:01, 41.60it/s, resid=5.69E-04]
#
# LinearLeastSquares:  45%|████▌     | 45/100 [00:01<00:01, 41.60it/s, resid=5.49E-04]
#
# LinearLeastSquares:  46%|████▌     | 46/100 [00:01<00:01, 41.60it/s, resid=5.31E-04]
#
# LinearLeastSquares:  47%|████▋     | 47/100 [00:01<00:01, 41.60it/s, resid=5.13E-04]
#
# LinearLeastSquares:  48%|████▊     | 48/100 [00:01<00:01, 41.71it/s, resid=5.13E-04]
#
# LinearLeastSquares:  48%|████▊     | 48/100 [00:01<00:01, 41.71it/s, resid=4.96E-04]
#
# LinearLeastSquares:  49%|████▉     | 49/100 [00:01<00:01, 41.71it/s, resid=4.80E-04]
#
# LinearLeastSquares:  50%|█████     | 50/100 [00:01<00:01, 41.71it/s, resid=4.64E-04]
#
# LinearLeastSquares:  51%|█████     | 51/100 [00:01<00:01, 41.71it/s, resid=4.49E-04]
#
# LinearLeastSquares:  52%|█████▏    | 52/100 [00:01<00:01, 41.71it/s, resid=4.34E-04]
#
# LinearLeastSquares:  53%|█████▎    | 53/100 [00:01<00:01, 42.06it/s, resid=4.34E-04]
#
# LinearLeastSquares:  53%|█████▎    | 53/100 [00:01<00:01, 42.06it/s, resid=4.20E-04]
#
# LinearLeastSquares:  54%|█████▍    | 54/100 [00:01<00:01, 42.06it/s, resid=4.07E-04]
#
# LinearLeastSquares:  55%|█████▌    | 55/100 [00:01<00:01, 42.06it/s, resid=3.94E-04]
#
# LinearLeastSquares:  56%|█████▌    | 56/100 [00:01<00:01, 42.06it/s, resid=3.82E-04]
#
# LinearLeastSquares:  57%|█████▋    | 57/100 [00:01<00:01, 42.06it/s, resid=3.70E-04]
#
# LinearLeastSquares:  58%|█████▊    | 58/100 [00:01<00:00, 42.51it/s, resid=3.70E-04]
#
# LinearLeastSquares:  58%|█████▊    | 58/100 [00:01<00:00, 42.51it/s, resid=3.58E-04]
#
# LinearLeastSquares:  59%|█████▉    | 59/100 [00:01<00:00, 42.51it/s, resid=3.47E-04]
#
# LinearLeastSquares:  60%|██████    | 60/100 [00:01<00:00, 42.51it/s, resid=3.37E-04]
#
# LinearLeastSquares:  61%|██████    | 61/100 [00:01<00:00, 42.51it/s, resid=3.26E-04]
#
# LinearLeastSquares:  62%|██████▏   | 62/100 [00:01<00:00, 42.51it/s, resid=3.16E-04]
#
# LinearLeastSquares:  63%|██████▎   | 63/100 [00:01<00:00, 42.60it/s, resid=3.16E-04]
#
# LinearLeastSquares:  63%|██████▎   | 63/100 [00:01<00:00, 42.60it/s, resid=3.07E-04]
#
# LinearLeastSquares:  64%|██████▍   | 64/100 [00:01<00:00, 42.60it/s, resid=2.98E-04]
#
# LinearLeastSquares:  65%|██████▌   | 65/100 [00:01<00:00, 42.60it/s, resid=2.89E-04]
#
# LinearLeastSquares:  66%|██████▌   | 66/100 [00:01<00:00, 42.60it/s, resid=2.80E-04]
#
# LinearLeastSquares:  67%|██████▋   | 67/100 [00:01<00:00, 42.60it/s, resid=2.72E-04]
#
# LinearLeastSquares:  68%|██████▊   | 68/100 [00:01<00:00, 42.53it/s, resid=2.72E-04]
#
# LinearLeastSquares:  68%|██████▊   | 68/100 [00:01<00:00, 42.53it/s, resid=2.64E-04]
#
# LinearLeastSquares:  69%|██████▉   | 69/100 [00:01<00:00, 42.53it/s, resid=2.57E-04]
#
# LinearLeastSquares:  70%|███████   | 70/100 [00:01<00:00, 42.53it/s, resid=2.49E-04]
#
# LinearLeastSquares:  71%|███████   | 71/100 [00:01<00:00, 42.53it/s, resid=2.42E-04]
#
# LinearLeastSquares:  72%|███████▏  | 72/100 [00:01<00:00, 42.53it/s, resid=2.35E-04]
#
# LinearLeastSquares:  73%|███████▎  | 73/100 [00:01<00:00, 43.16it/s, resid=2.35E-04]
#
# LinearLeastSquares:  73%|███████▎  | 73/100 [00:01<00:00, 43.16it/s, resid=2.29E-04]
#
# LinearLeastSquares:  74%|███████▍  | 74/100 [00:01<00:00, 43.16it/s, resid=2.22E-04]
#
# LinearLeastSquares:  75%|███████▌  | 75/100 [00:01<00:00, 43.16it/s, resid=2.16E-04]
#
# LinearLeastSquares:  76%|███████▌  | 76/100 [00:01<00:00, 43.16it/s, resid=2.10E-04]
#
# LinearLeastSquares:  77%|███████▋  | 77/100 [00:01<00:00, 43.16it/s, resid=2.04E-04]
#
# LinearLeastSquares:  78%|███████▊  | 78/100 [00:01<00:00, 43.16it/s, resid=2.04E-04]
#
# LinearLeastSquares:  78%|███████▊  | 78/100 [00:01<00:00, 43.16it/s, resid=1.99E-04]
#
# LinearLeastSquares:  79%|███████▉  | 79/100 [00:01<00:00, 43.16it/s, resid=1.93E-04]
#
# LinearLeastSquares:  80%|████████  | 80/100 [00:01<00:00, 43.16it/s, resid=1.88E-04]
#
# LinearLeastSquares:  81%|████████  | 81/100 [00:01<00:00, 43.16it/s, resid=1.83E-04]
#
# LinearLeastSquares:  82%|████████▏ | 82/100 [00:01<00:00, 43.16it/s, resid=1.78E-04]
#
# LinearLeastSquares:  83%|████████▎ | 83/100 [00:01<00:00, 40.65it/s, resid=1.78E-04]
#
# LinearLeastSquares:  83%|████████▎ | 83/100 [00:02<00:00, 40.65it/s, resid=1.74E-04]
#
# LinearLeastSquares:  84%|████████▍ | 84/100 [00:02<00:00, 40.65it/s, resid=1.69E-04]
#
# LinearLeastSquares:  85%|████████▌ | 85/100 [00:02<00:00, 40.65it/s, resid=1.65E-04]
#
# LinearLeastSquares:  86%|████████▌ | 86/100 [00:02<00:00, 40.65it/s, resid=1.60E-04]
#
# LinearLeastSquares:  87%|████████▋ | 87/100 [00:02<00:00, 40.65it/s, resid=1.56E-04]
#
# LinearLeastSquares:  88%|████████▊ | 88/100 [00:02<00:00, 41.30it/s, resid=1.56E-04]
#
# LinearLeastSquares:  88%|████████▊ | 88/100 [00:02<00:00, 41.30it/s, resid=1.52E-04]
#
# LinearLeastSquares:  89%|████████▉ | 89/100 [00:02<00:00, 41.30it/s, resid=1.48E-04]
#
# LinearLeastSquares:  90%|█████████ | 90/100 [00:02<00:00, 41.30it/s, resid=1.45E-04]
#
# LinearLeastSquares:  91%|█████████ | 91/100 [00:02<00:00, 41.30it/s, resid=1.41E-04]
#
# LinearLeastSquares:  92%|█████████▏| 92/100 [00:02<00:00, 41.30it/s, resid=1.38E-04]
#
# LinearLeastSquares:  93%|█████████▎| 93/100 [00:02<00:00, 41.66it/s, resid=1.38E-04]
#
# LinearLeastSquares:  93%|█████████▎| 93/100 [00:02<00:00, 41.66it/s, resid=1.34E-04]
#
# LinearLeastSquares:  94%|█████████▍| 94/100 [00:02<00:00, 41.66it/s, resid=1.31E-04]
#
# LinearLeastSquares:  95%|█████████▌| 95/100 [00:02<00:00, 41.66it/s, resid=1.28E-04]
#
# LinearLeastSquares:  96%|█████████▌| 96/100 [00:02<00:00, 41.66it/s, resid=1.25E-04]
#
# LinearLeastSquares:  97%|█████████▋| 97/100 [00:02<00:00, 41.66it/s, resid=1.22E-04]
#
# LinearLeastSquares:  98%|█████████▊| 98/100 [00:02<00:00, 41.74it/s, resid=1.22E-04]
#
# LinearLeastSquares:  98%|█████████▊| 98/100 [00:02<00:00, 41.74it/s, resid=1.19E-04]
#
# LinearLeastSquares:  99%|█████████▉| 99/100 [00:02<00:00, 41.74it/s, resid=1.16E-04]
#
# LinearLeastSquares: 100%|██████████| 100/100 [00:02<00:00, 41.78it/s, resid=1.16E-04]
#
# MaxEig:   0%|          | 0/30 [00:00<?, ?it/s]
#
# MaxEig:   0%|          | 0/30 [00:00<?, ?it/s, max_eig=2.60E+02]
#
# MaxEig:   3%|▎         | 1/30 [00:00<00:01, 23.15it/s, max_eig=4.43E+01]
#
# MaxEig:   7%|▋         | 2/30 [00:00<00:00, 30.36it/s, max_eig=1.38E+02]
#
# MaxEig:  10%|█         | 3/30 [00:00<00:00, 34.82it/s, max_eig=1.55E+02]
#
# MaxEig:  13%|█▎        | 4/30 [00:00<00:00, 37.16it/s, max_eig=1.57E+02]
#
# MaxEig:  17%|█▋        | 5/30 [00:00<00:00, 45.66it/s, max_eig=1.57E+02]
#
# MaxEig:  17%|█▋        | 5/30 [00:00<00:00, 45.66it/s, max_eig=1.57E+02]
#
# MaxEig:  20%|██        | 6/30 [00:00<00:00, 45.66it/s, max_eig=1.57E+02]
#
# MaxEig:  23%|██▎       | 7/30 [00:00<00:00, 45.66it/s, max_eig=1.57E+02]
# 3
# MaxEig:  27%|██▋       | 8/30 [00:00<00:00, 45.66it/s, max_eig=1.57E+02]
#
# MaxEig:  30%|███       | 9/30 [00:00<00:00, 45.66it/s, max_eig=1.57E+02]
#
# MaxEig:  33%|███▎      | 10/30 [00:00<00:00, 44.74it/s, max_eig=1.57E+02]
#
# MaxEig:  33%|███▎      | 10/30 [00:00<00:00, 44.74it/s, max_eig=1.57E+02]
#
# MaxEig:  37%|███▋      | 11/30 [00:00<00:00, 44.74it/s, max_eig=1.57E+02]
#
# MaxEig:  40%|████      | 12/30 [00:00<00:00, 44.74it/s, max_eig=1.57E+02]
#
# MaxEig:  43%|████▎     | 13/30 [00:00<00:00, 44.74it/s, max_eig=1.57E+02]
#
# MaxEig:  47%|████▋     | 14/30 [00:00<00:00, 44.74it/s, max_eig=1.57E+02]
#
# MaxEig:  50%|█████     | 15/30 [00:00<00:00, 44.73it/s, max_eig=1.57E+02]
#
# MaxEig:  50%|█████     | 15/30 [00:00<00:00, 44.73it/s, max_eig=1.57E+02]
#
# MaxEig:  53%|█████▎    | 16/30 [00:00<00:00, 44.73it/s, max_eig=1.57E+02]
#
# MaxEig:  57%|█████▋    | 17/30 [00:00<00:00, 44.73it/s, max_eig=1.57E+02]
#
# MaxEig:  60%|██████    | 18/30 [00:00<00:00, 44.73it/s, max_eig=1.57E+02]
#
# MaxEig:  63%|██████▎   | 19/30 [00:00<00:00, 44.73it/s, max_eig=1.57E+02]
#
# MaxEig:  67%|██████▋   | 20/30 [00:00<00:00, 44.72it/s, max_eig=1.57E+02]
#
# MaxEig:  67%|██████▋   | 20/30 [00:00<00:00, 44.72it/s, max_eig=1.57E+02]
#
# MaxEig:  70%|███████   | 21/30 [00:00<00:00, 44.72it/s, max_eig=1.57E+02]
#
# MaxEig:  73%|███████▎  | 22/30 [00:00<00:00, 44.72it/s, max_eig=1.57E+02]
#
# MaxEig:  77%|███████▋  | 23/30 [00:00<00:00, 44.72it/s, max_eig=1.57E+02]
#
# MaxEig:  80%|████████  | 24/30 [00:00<00:00, 44.72it/s, max_eig=1.57E+02]
#
# MaxEig:  83%|████████▎ | 25/30 [00:00<00:00, 45.01it/s, max_eig=1.57E+02]
#
# MaxEig:  83%|████████▎ | 25/30 [00:00<00:00, 45.01it/s, max_eig=1.57E+02]
#
# MaxEig:  87%|████████▋ | 26/30 [00:00<00:00, 45.01it/s, max_eig=1.57E+02]
#
# MaxEig:  90%|█████████ | 27/30 [00:00<00:00, 45.01it/s, max_eig=1.57E+02]
#
# MaxEig:  93%|█████████▎| 28/30 [00:00<00:00, 45.01it/s, max_eig=1.57E+02]
#
# MaxEig:  97%|█████████▋| 29/30 [00:00<00:00, 45.01it/s, max_eig=1.57E+02]
#
# MaxEig: 100%|██████████| 30/30 [00:00<00:00, 45.10it/s, max_eig=1.57E+02]
#
# LinearLeastSquares:   0%|          | 0/100 [00:00<?, ?it/s]
#
# LinearLeastSquares:   0%|          | 0/100 [00:00<?, ?it/s, resid=3.38E-02]
#
# LinearLeastSquares:   1%|          | 1/100 [00:00<00:04, 21.76it/s, resid=1.89E-02]
#
# LinearLeastSquares:   2%|▏         | 2/100 [00:00<00:03, 29.20it/s, resid=1.46E-02]
#
# LinearLeastSquares:   3%|▎         | 3/100 [00:00<00:02, 33.12it/s, resid=1.13E-02]
#
# LinearLeastSquares:   4%|▍         | 4/100 [00:00<00:02, 35.59it/s, resid=8.83E-03]
#
# LinearLeastSquares:   5%|▌         | 5/100 [00:00<00:02, 43.84it/s, resid=8.83E-03]
#
# LinearLeastSquares:   5%|▌         | 5/100 [00:00<00:02, 43.84it/s, resid=6.98E-03]
#
# LinearLeastSquares:   6%|▌         | 6/100 [00:00<00:02, 43.84it/s, resid=5.58E-03]
#
# LinearLeastSquares:   7%|▋         | 7/100 [00:00<00:02, 43.84it/s, resid=4.51E-03]
#
# LinearLeastSquares:   8%|▊         | 8/100 [00:00<00:02, 43.84it/s, resid=3.68E-03]
#
# LinearLeastSquares:   9%|▉         | 9/100 [00:00<00:02, 43.84it/s, resid=3.04E-03]
#
# LinearLeastSquares:  10%|█         | 10/100 [00:00<00:02, 43.55it/s, resid=3.04E-03]
#
# LinearLeastSquares:  10%|█         | 10/100 [00:00<00:02, 43.55it/s, resid=2.54E-03]
#
# LinearLeastSquares:  11%|█         | 11/100 [00:00<00:02, 43.55it/s, resid=2.15E-03]
#
# LinearLeastSquares:  12%|█▏        | 12/100 [00:00<00:02, 43.55it/s, resid=1.84E-03]
#
# LinearLeastSquares:  13%|█▎        | 13/100 [00:00<00:01, 43.55it/s, resid=1.60E-03]
#
# LinearLeastSquares:  14%|█▍        | 14/100 [00:00<00:01, 43.55it/s, resid=1.41E-03]
#
# LinearLeastSquares:  15%|█▌        | 15/100 [00:00<00:01, 42.63it/s, resid=1.41E-03]
#
# LinearLeastSquares:  15%|█▌        | 15/100 [00:00<00:01, 42.63it/s, resid=1.25E-03]
#
# LinearLeastSquares:  16%|█▌        | 16/100 [00:00<00:01, 42.63it/s, resid=1.13E-03]
#
# LinearLeastSquares:  17%|█▋        | 17/100 [00:00<00:01, 42.63it/s, resid=1.03E-03]
#
# LinearLeastSquares:  18%|█▊        | 18/100 [00:00<00:01, 42.63it/s, resid=9.47E-04]
#
# LinearLeastSquares:  19%|█▉        | 19/100 [00:00<00:01, 42.63it/s, resid=8.78E-04]
#
# LinearLeastSquares:  20%|██        | 20/100 [00:00<00:01, 42.19it/s, resid=8.78E-04]
#
# LinearLeastSquares:  20%|██        | 20/100 [00:00<00:01, 42.19it/s, resid=8.20E-04]
#
# LinearLeastSquares:  21%|██        | 21/100 [00:00<00:01, 42.19it/s, resid=7.70E-04]
#
# LinearLeastSquares:  22%|██▏       | 22/100 [00:00<00:01, 42.19it/s, resid=7.26E-04]
#
# LinearLeastSquares:  23%|██▎       | 23/100 [00:00<00:01, 42.19it/s, resid=6.88E-04]
#
# LinearLeastSquares:  24%|██▍       | 24/100 [00:00<00:01, 42.19it/s, resid=6.53E-04]
#
# LinearLeastSquares:  25%|██▌       | 25/100 [00:00<00:01, 42.63it/s, resid=6.53E-04]
#
# LinearLeastSquares:  25%|██▌       | 25/100 [00:00<00:01, 42.63it/s, resid=6.22E-04]
#
# LinearLeastSquares:  26%|██▌       | 26/100 [00:00<00:01, 42.63it/s, resid=5.94E-04]
#
# LinearLeastSquares:  27%|██▋       | 27/100 [00:00<00:01, 42.63it/s, resid=5.68E-04]
#
# LinearLeastSquares:  28%|██▊       | 28/100 [00:00<00:01, 42.63it/s, resid=5.44E-04]
#
# LinearLeastSquares:  29%|██▉       | 29/100 [00:00<00:01, 42.63it/s, resid=5.21E-04]
#
# LinearLeastSquares:  30%|███       | 30/100 [00:00<00:01, 42.37it/s, resid=5.21E-04]
#
# LinearLeastSquares:  30%|███       | 30/100 [00:00<00:01, 42.37it/s, resid=5.00E-04]
#
# LinearLeastSquares:  31%|███       | 31/100 [00:00<00:01, 42.37it/s, resid=4.81E-04]
#
# LinearLeastSquares:  32%|███▏      | 32/100 [00:00<00:01, 42.37it/s, resid=4.62E-04]
#
# LinearLeastSquares:  33%|███▎      | 33/100 [00:00<00:01, 42.37it/s, resid=4.45E-04]
#
# LinearLeastSquares:  34%|███▍      | 34/100 [00:00<00:01, 42.37it/s, resid=4.28E-04]
#
# LinearLeastSquares:  35%|███▌      | 35/100 [00:00<00:01, 42.38it/s, resid=4.28E-04]
#
# LinearLeastSquares:  35%|███▌      | 35/100 [00:00<00:01, 42.38it/s, resid=4.12E-04]
#
# LinearLeastSquares:  36%|███▌      | 36/100 [00:00<00:01, 42.38it/s, resid=3.97E-04]
#
# LinearLeastSquares:  37%|███▋      | 37/100 [00:00<00:01, 42.38it/s, resid=3.83E-04]
#
# LinearLeastSquares:  38%|███▊      | 38/100 [00:00<00:01, 42.38it/s, resid=3.69E-04]
#
# LinearLeastSquares:  39%|███▉      | 39/100 [00:00<00:01, 39.37it/s, resid=3.69E-04]
#
# LinearLeastSquares:  39%|███▉      | 39/100 [00:00<00:01, 39.37it/s, resid=3.56E-04]
#
# LinearLeastSquares:  40%|████      | 40/100 [00:01<00:01, 39.37it/s, resid=3.44E-04]
#
# LinearLeastSquares:  41%|████      | 41/100 [00:01<00:01, 39.37it/s, resid=3.32E-04]
#
# LinearLeastSquares:  42%|████▏     | 42/100 [00:01<00:01, 39.37it/s, resid=3.20E-04]
#
# LinearLeastSquares:  43%|████▎     | 43/100 [00:01<00:01, 38.52it/s, resid=3.20E-04]
#
# LinearLeastSquares:  43%|████▎     | 43/100 [00:01<00:01, 38.52it/s, resid=3.09E-04]
#
# LinearLeastSquares:  44%|████▍     | 44/100 [00:01<00:01, 38.52it/s, resid=2.99E-04]
#
# LinearLeastSquares:  45%|████▌     | 45/100 [00:01<00:01, 38.52it/s, resid=2.89E-04]
#
# LinearLeastSquares:  46%|████▌     | 46/100 [00:01<00:01, 38.52it/s, resid=2.79E-04]
#
# LinearLeastSquares:  47%|████▋     | 47/100 [00:01<00:01, 38.52it/s, resid=2.70E-04]
#
# LinearLeastSquares:  48%|████▊     | 48/100 [00:01<00:01, 39.84it/s, resid=2.70E-04]
#
# LinearLeastSquares:  48%|████▊     | 48/100 [00:01<00:01, 39.84it/s, resid=2.61E-04]
#
# LinearLeastSquares:  49%|████▉     | 49/100 [00:01<00:01, 39.84it/s, resid=2.53E-04]
#
# LinearLeastSquares:  50%|█████     | 50/100 [00:01<00:01, 39.84it/s, resid=2.45E-04]
#
# LinearLeastSquares:  51%|█████     | 51/100 [00:01<00:01, 39.84it/s, resid=2.37E-04]
#
# LinearLeastSquares:  52%|█████▏    | 52/100 [00:01<00:01, 39.55it/s, resid=2.37E-04]
#
# ...
#
# LinearLeastSquares:  74%|███████▍  | 74/100 [00:01<00:00, 45.92it/s, resid=1.27E-04]
#
# LinearLeastSquares:  75%|███████▌  | 75/100 [00:01<00:00, 45.92it/s, resid=1.24E-04]
#
# LinearLeastSquares:  76%|███████▌  | 76/100 [00:01<00:00, 45.92it/s, resid=1.21E-04]
#
# LinearLeastSquares:  77%|███████▋  | 77/100 [00:01<00:00, 45.92it/s, resid=1.17E-04]
#
# LinearLeastSquares:  78%|███████▊  | 78/100 [00:01<00:00, 44.02it/s, resid=1.17E-04]
#
# LinearLeastSquares:  78%|███████▊  | 78/100 [00:01<00:00, 44.02it/s, resid=1.14E-04]
#
# LinearLeastSquares:  79%|███████▉  | 79/100 [00:01<00:00, 44.02it/s, resid=1.12E-04]
#
# LinearLeastSquares:  80%|████████  | 80/100 [00:01<00:00, 44.02it/s, resid=1.09E-04]
#
# LinearLeastSquares:  81%|████████  | 81/100 [00:01<00:00, 44.02it/s, resid=1.06E-04]
#
# LinearLeastSquares:  82%|████████▏ | 82/100 [00:01<00:00, 44.02it/s, resid=1.03E-04]
#
# LinearLeastSquares:  83%|████████▎ | 83/100 [00:01<00:00, 43.43it/s, resid=1.03E-04]
#
# LinearLeastSquares:  83%|████████▎ | 83/100 [00:01<00:00, 43.43it/s, resid=1.01E-04]
#
# LinearLeastSquares:  84%|████████▍ | 84/100 [00:01<00:00, 43.43it/s, resid=9.82E-05]
#
# LinearLeastSquares:  85%|████████▌ | 85/100 [00:01<00:00, 43.43it/s, resid=9.57E-05]
#
# LinearLeastSquares:  86%|████████▌ | 86/100 [00:01<00:00, 43.43it/s, resid=9.34E-05]
#
# LinearLeastSquares:  87%|████████▋ | 87/100 [00:02<00:00, 43.43it/s, resid=9.11E-05]
#
# LinearLeastSquares:  88%|████████▊ | 88/100 [00:02<00:00, 42.51it/s, resid=9.11E-05]
#
# LinearLeastSquares:  88%|████████▊ | 88/100 [00:02<00:00, 42.51it/s, resid=8.89E-05]
#
# LinearLeastSquares:  89%|████████▉ | 89/100 [00:02<00:00, 42.51it/s, resid=8.67E-05]
#
# LinearLeastSquares:  90%|█████████ | 90/100 [00:02<00:00, 42.51it/s, resid=8.46E-05]
#
# LinearLeastSquares:  91%|█████████ | 91/100 [00:02<00:00, 42.51it/s, resid=8.26E-05]
#
# LinearLeastSquares:  92%|█████████▏| 92/100 [00:02<00:00, 42.51it/s, resid=8.06E-05]
#
# LinearLeastSquares:  93%|█████████▎| 93/100 [00:02<00:00, 41.81it/s, resid=8.06E-05]
#
# LinearLeastSquares:  93%|█████████▎| 93/100 [00:02<00:00, 41.81it/s, resid=7.87E-05]
#
# LinearLeastSquares:  94%|█████████▍| 94/100 [00:02<00:00, 41.81it/s, resid=7.69E-05]
#
# LinearLeastSquares:  95%|█████████▌| 95/100 [00:02<00:00, 41.81it/s, resid=7.51E-05]
#
# LinearLeastSquares:  96%|█████████▌| 96/100 [00:02<00:00, 41.81it/s, resid=7.33E-05]
#
# LinearLeastSquares:  97%|█████████▋| 97/100 [00:02<00:00, 41.81it/s, resid=7.16E-05]
#
# LinearLeastSquares:  98%|█████████▊| 98/100 [00:02<00:00, 42.31it/s, resid=7.16E-05]
#
# LinearLeastSquares:  98%|█████████▊| 98/100 [00:02<00:00, 42.31it/s, resid=7.00E-05]
#
# LinearLeastSquares:  99%|█████████▉| 99/100 [00:02<00:00, 42.31it/s, resid=6.84E-05]
#
# LinearLeastSquares: 100%|██████████| 100/100 [00:02<00:00, 43.56it/s, resid=6.84E-05]
#
# MaxEig:   0%|          | 0/30 [00:00<?, ?it/s]
#
# MaxEig:   0%|          | 0/30 [00:00<?, ?it/s, max_eig=3.49E+02]
#
# MaxEig:   3%|▎         | 1/30 [00:00<00:01, 26.64it/s, max_eig=1.10E+02]
#
# MaxEig:   7%|▋         | 2/30 [00:00<00:00, 35.10it/s, max_eig=1.56E+02]
#
# MaxEig:  10%|█         | 3/30 [00:00<00:00, 36.13it/s, max_eig=1.57E+02]
#
# MaxEig:  13%|█▎        | 4/30 [00:00<00:00, 38.43it/s, max_eig=1.57E+02]
#
# MaxEig:  17%|█▋        | 5/30 [00:00<00:00, 47.47it/s, max_eig=1.57E+02]
#
# MaxEig:  17%|█▋        | 5/30 [00:00<00:00, 47.47it/s, max_eig=1.57E+02]
#
# MaxEig:  20%|██        | 6/30 [00:00<00:00, 47.47it/s, max_eig=1.57E+02]
#
# MaxEig:  23%|██▎       | 7/30 [00:00<00:00, 47.47it/s, max_eig=1.57E+02]
# 11
# MaxEig:  27%|██▋       | 8/30 [00:00<00:00, 47.47it/s, max_eig=1.57E+02]
#
# MaxEig:  30%|███       | 9/30 [00:00<00:00, 44.09it/s, max_eig=1.57E+02]
#
# MaxEig:  30%|███       | 9/30 [00:00<00:00, 44.09it/s, max_eig=1.57E+02]
#
# MaxEig:  33%|███▎      | 10/30 [00:00<00:00, 44.09it/s, max_eig=1.57E+02]
#
# MaxEig:  37%|███▋      | 11/30 [00:00<00:00, 44.09it/s, max_eig=1.57E+02]
#
# MaxEig:  40%|████      | 12/30 [00:00<00:00, 44.09it/s, max_eig=1.57E+02]
#
# MaxEig:  43%|████▎     | 13/30 [00:00<00:00, 44.09it/s, max_eig=1.57E+02]
#
# MaxEig:  47%|████▋     | 14/30 [00:00<00:00, 45.45it/s, max_eig=1.57E+02]
#
# MaxEig:  47%|████▋     | 14/30 [00:00<00:00, 45.45it/s, max_eig=1.57E+02]
#
# MaxEig:  50%|█████     | 15/30 [00:00<00:00, 45.45it/s, max_eig=1.57E+02]
#
# MaxEig:  53%|█████▎    | 16/30 [00:00<00:00, 45.45it/s, max_eig=1.57E+02]
#
# MaxEig:  57%|█████▋    | 17/30 [00:00<00:00, 45.45it/s, max_eig=1.57E+02]
#
# MaxEig:  60%|██████    | 18/30 [00:00<00:00, 45.45it/s, max_eig=1.57E+02]
#
# MaxEig:  63%|██████▎   | 19/30 [00:00<00:00, 46.43it/s, max_eig=1.57E+02]
#
# MaxEig:  63%|██████▎   | 19/30 [00:00<00:00, 46.43it/s, max_eig=1.57E+02]
#
# MaxEig:  67%|██████▋   | 20/30 [00:00<00:00, 46.43it/s, max_eig=1.57E+02]
#
# MaxEig:  70%|███████   | 21/30 [00:00<00:00, 46.43it/s, max_eig=1.57E+02]
#
# MaxEig:  73%|███████▎  | 22/30 [00:00<00:00, 46.43it/s, max_eig=1.57E+02]
#
# MaxEig:  77%|███████▋  | 23/30 [00:00<00:00, 46.43it/s, max_eig=1.57E+02]
#
# MaxEig:  80%|████████  | 24/30 [00:00<00:00, 47.11it/s, max_eig=1.57E+02]
#
# MaxEig:  80%|████████  | 24/30 [00:00<00:00, 47.11it/s, max_eig=1.57E+02]
#
# MaxEig:  83%|████████▎ | 25/30 [00:00<00:00, 47.11it/s, max_eig=1.57E+02]
#
# MaxEig:  87%|████████▋ | 26/30 [00:00<00:00, 47.11it/s, max_eig=1.57E+02]
#
# MaxEig:  90%|█████████ | 27/30 [00:00<00:00, 47.11it/s, max_eig=1.57E+02]
#
# MaxEig:  93%|█████████▎| 28/30 [00:00<00:00, 47.11it/s, max_eig=1.57E+02]
#
# MaxEig:  97%|█████████▋| 29/30 [00:00<00:00, 47.73it/s, max_eig=1.57E+02]
#
# MaxEig:  97%|█████████▋| 29/30 [00:00<00:00, 47.73it/s, max_eig=1.57E+02]
#
# MaxEig: 100%|██████████| 30/30 [00:00<00:00, 46.60it/s, max_eig=1.57E+02]
#
# LinearLeastSquares:   0%|          | 0/100 [00:00<?, ?it/s]
#
# LinearLeastSquares:   0%|          | 0/100 [00:00<?, ?it/s, resid=4.49E-02]
#
# LinearLeastSquares:   1%|          | 1/100 [00:00<00:05, 18.15it/s, resid=1.58E-02]
#
# LinearLeastSquares:   2%|▏         | 2/100 [00:00<00:03, 26.41it/s, resid=1.11E-02]
#
# LinearLeastSquares:   3%|▎         | 3/100 [00:00<00:03, 31.28it/s, resid=8.03E-03]
#
# LinearLeastSquares:   4%|▍         | 4/100 [00:00<00:02, 34.34it/s, resid=5.97E-03]
#
# LinearLeastSquares:   5%|▌         | 5/100 [00:00<00:02, 42.55it/s, resid=5.97E-03]
#
# LinearLeastSquares:   5%|▌         | 5/100 [00:00<00:02, 42.55it/s, resid=4.57E-03]
#
# LinearLeastSquares:   6%|▌         | 6/100 [00:00<00:02, 42.55it/s, resid=3.58E-03]
#
# LinearLeastSquares:   7%|▋         | 7/100 [00:00<00:02, 42.55it/s, resid=2.86E-03]
#
# LinearLeastSquares:   8%|▊         | 8/100 [00:00<00:02, 42.55it/s, resid=2.32E-03]
#
# LinearLeastSquares:   9%|▉         | 9/100 [00:00<00:02, 42.55it/s, resid=1.91E-03]
#
# LinearLeastSquares:  10%|█         | 10/100 [00:00<00:02, 44.03it/s, resid=1.91E-03]
#
# LinearLeastSquares:  10%|█         | 10/100 [00:00<00:02, 44.03it/s, resid=1.59E-03]
#
# LinearLeastSquares:  11%|█         | 11/100 [00:00<00:02, 44.03it/s, resid=1.34E-03]
#
# LinearLeastSquares:  12%|█▏        | 12/100 [00:00<00:01, 44.03it/s, resid=1.14E-03]
#
# LinearLeastSquares:  13%|█▎        | 13/100 [00:00<00:01, 44.03it/s, resid=9.81E-04]
#
# LinearLeastSquares:  14%|█▍        | 14/100 [00:00<00:01, 44.03it/s, resid=8.53E-04]
#
# LinearLeastSquares:  15%|█▌        | 15/100 [00:00<00:01, 45.19it/s, resid=8.53E-04]
#
# LinearLeastSquares:  15%|█▌        | 15/100 [00:00<00:01, 45.19it/s, resid=7.50E-04]
#
# LinearLeastSquares:  16%|█▌        | 16/100 [00:00<00:01, 45.19it/s, resid=6.66E-04]
#
# LinearLeastSquares:  17%|█▋        | 17/100 [00:00<00:01, 45.19it/s, resid=5.97E-04]
#
# LinearLeastSquares:  18%|█▊        | 18/100 [00:00<00:01, 45.19it/s, resid=5.40E-04]
#
# LinearLeastSquares:  19%|█▉        | 19/100 [00:00<00:01, 45.19it/s, resid=4.92E-04]
#
# LinearLeastSquares:  20%|██        | 20/100 [00:00<00:01, 46.06it/s, resid=4.92E-04]
#
# LinearLeastSquares:  20%|██        | 20/100 [00:00<00:01, 46.06it/s, resid=4.52E-04]
#
# LinearLeastSquares:  21%|██        | 21/100 [00:00<00:01, 46.06it/s, resid=4.18E-04]
#
# LinearLeastSquares:  22%|██▏       | 22/100 [00:00<00:01, 46.06it/s, resid=3.89E-04]
#
# LinearLeastSquares:  23%|██▎       | 23/100 [00:00<00:01, 46.06it/s, resid=3.64E-04]
#
# LinearLeastSquares:  24%|██▍       | 24/100 [00:00<00:01, 46.06it/s, resid=3.42E-04]
#
# LinearLeastSquares:  25%|██▌       | 25/100 [00:00<00:01, 46.63it/s, resid=3.42E-04]
#
# LinearLeastSquares:  25%|██▌       | 25/100 [00:00<00:01, 46.63it/s, resid=3.23E-04]
#
# LinearLeastSquares:  26%|██▌       | 26/100 [00:00<00:01, 46.63it/s, resid=3.06E-04]
#
# LinearLeastSquares:  27%|██▋       | 27/100 [00:00<00:01, 46.63it/s, resid=2.91E-04]
#
# LinearLeastSquares:  28%|██▊       | 28/100 [00:00<00:01, 46.63it/s, resid=2.77E-04]
#
# LinearLeastSquares:  29%|██▉       | 29/100 [00:00<00:01, 46.63it/s, resid=2.65E-04]
#
# LinearLeastSquares:  30%|███       | 30/100 [00:00<00:01, 46.12it/s, resid=2.65E-04]
#
# LinearLeastSquares:  30%|███       | 30/100 [00:00<00:01, 46.12it/s, resid=2.53E-04]
#
# LinearLeastSquares:  31%|███       | 31/100 [00:00<00:01, 46.12it/s, resid=2.43E-04]
#
# LinearLeastSquares:  32%|███▏      | 32/100 [00:00<00:01, 46.12it/s, resid=2.33E-04]
#
# LinearLeastSquares:  33%|███▎      | 33/100 [00:00<00:01, 46.12it/s, resid=2.24E-04]
#
# LinearLeastSquares:  34%|███▍      | 34/100 [00:00<00:01, 46.12it/s, resid=2.16E-04]
#
# LinearLeastSquares:  35%|███▌      | 35/100 [00:00<00:01, 45.37it/s, resid=2.16E-04]
#
# LinearLeastSquares:  35%|███▌      | 35/100 [00:00<00:01, 45.37it/s, resid=2.08E-04]
#
# LinearLeastSquares:  36%|███▌      | 36/100 [00:00<00:01, 45.37it/s, resid=2.01E-04]
#
# LinearLeastSquares:  37%|███▋      | 37/100 [00:00<00:01, 45.37it/s, resid=1.94E-04]
#
# LinearLeastSquares:  38%|███▊      | 38/100 [00:00<00:01, 45.37it/s, resid=1.87E-04]
#
# LinearLeastSquares:  39%|███▉      | 39/100 [00:00<00:01, 45.37it/s, resid=1.81E-04]
#
# LinearLeastSquares:  40%|████      | 40/100 [00:00<00:01, 44.95it/s, resid=1.81E-04]
#
# LinearLeastSquares:  40%|████      | 40/100 [00:00<00:01, 44.95it/s, resid=1.75E-04]
#
# LinearLeastSquares:  41%|████      | 41/100 [00:00<00:01, 44.95it/s, resid=1.69E-04]
#
# LinearLeastSquares:  42%|████▏     | 42/100 [00:00<00:01, 44.95it/s, resid=1.64E-04]
#
# LinearLeastSquares:  43%|████▎     | 43/100 [00:00<00:01, 44.95it/s, resid=1.59E-04]
#
# LinearLeastSquares:  44%|████▍     | 44/100 [00:01<00:01, 44.95it/s, resid=1.54E-04]
#
# LinearLeastSquares:  45%|████▌     | 45/100 [00:01<00:01, 42.71it/s, resid=1.54E-04]
#
# LinearLeastSquares:  45%|████▌     | 45/100 [00:01<00:01, 42.71it/s, resid=1.49E-04]
#
# LinearLeastSquares:  46%|████▌     | 46/100 [00:01<00:01, 42.71it/s, resid=1.45E-04]
#
# LinearLeastSquares:  47%|████▋     | 47/100 [00:01<00:01, 42.71it/s, resid=1.40E-04]
#
# LinearLeastSquares:  48%|████▊     | 48/100 [00:01<00:01, 42.71it/s, resid=1.36E-04]
#
# LinearLeastSquares:  49%|████▉     | 49/100 [00:01<00:01, 42.71it/s, resid=1.32E-04]
#
# LinearLeastSquares:  50%|█████     | 50/100 [00:01<00:01, 42.28it/s, resid=1.32E-04]
#
# LinearLeastSquares:  50%|█████     | 50/100 [00:01<00:01, 42.28it/s, resid=1.28E-04]
#
# LinearLeastSquares:  51%|█████     | 51/100 [00:01<00:01, 42.28it/s, resid=1.25E-04]
#
# LinearLeastSquares:  52%|█████▏    | 52/100 [00:01<00:01, 42.28it/s, resid=1.21E-04]
#
# LinearLeastSquares:  53%|█████▎    | 53/100 [00:01<00:01, 42.28it/s, resid=1.18E-04]
#
# LinearLeastSquares:  54%|█████▍    | 54/100 [00:01<00:01, 42.28it/s, resid=1.14E-04]
#
# LinearLeastSquares:  55%|█████▌    | 55/100 [00:01<00:01, 41.70it/s, resid=1.14E-04]
#
# LinearLeastSquares:  55%|█████▌    | 55/100 [00:01<00:01, 41.70it/s, resid=1.11E-04]
#
# LinearLeastSquares:  56%|█████▌    | 56/100 [00:01<00:01, 41.70it/s, resid=1.08E-04]
#
# LinearLeastSquares:  57%|█████▋    | 57/100 [00:01<00:01, 41.70it/s, resid=1.05E-04]
#
# LinearLeastSquares:  58%|█████▊    | 58/100 [00:01<00:01, 41.70it/s, resid=1.02E-04]
#
# LinearLeastSquares:  59%|█████▉    | 59/100 [00:01<00:00, 41.70it/s, resid=9.94E-05]
#
# LinearLeastSquares:  60%|██████    | 60/100 [00:01<00:00, 41.93it/s, resid=9.94E-05]
#
# LinearLeastSquares:  60%|██████    | 60/100 [00:01<00:00, 41.93it/s, resid=9.67E-05]
#
# LinearLeastSquares:  61%|██████    | 61/100 [00:01<00:00, 41.93it/s, resid=9.41E-05]
#
# LinearLeastSquares:  62%|██████▏   | 62/100 [00:01<00:00, 41.93it/s, resid=9.16E-05]
#
# LinearLeastSquares:  63%|██████▎   | 63/100 [00:01<00:00, 41.93it/s, resid=8.91E-05]
#
# LinearLeastSquares:  64%|██████▍   | 64/100 [00:01<00:00, 41.93it/s, resid=8.68E-05]
#
# LinearLeastSquares:  65%|██████▌   | 65/100 [00:01<00:00, 41.80it/s, resid=8.68E-05]
#
# LinearLeastSquares:  65%|██████▌   | 65/100 [00:01<00:00, 41.80it/s, resid=8.45E-05]
#
# LinearLeastSquares:  66%|██████▌   | 66/100 [00:01<00:00, 41.80it/s, resid=8.23E-05]
#
# LinearLeastSquares:  67%|██████▋   | 67/100 [00:01<00:00, 41.80it/s, resid=8.01E-05]
#
# LinearLeastSquares:  68%|██████▊   | 68/100 [00:01<00:00, 41.80it/s, resid=7.81E-05]
#
# LinearLeastSquares:  69%|██████▉   | 69/100 [00:01<00:00, 41.80it/s, resid=7.61E-05]
#
# LinearLeastSquares:  70%|███████   | 70/100 [00:01<00:00, 39.38it/s, resid=7.61E-05]
#
# LinearLeastSquares:  70%|███████   | 70/100 [00:01<00:00, 39.38it/s, resid=7.41E-05]
#
# LinearLeastSquares:  71%|███████   | 71/100 [00:01<00:00, 39.38it/s, resid=7.22E-05]
#
# LinearLeastSquares:  72%|███████▏  | 72/100 [00:01<00:00, 39.38it/s, resid=7.04E-05]
#
# LinearLeastSquares:  73%|███████▎  | 73/100 [00:01<00:00, 39.38it/s, resid=6.86E-05]
#
# LinearLeastSquares:  74%|███████▍  | 74/100 [00:01<00:00, 39.38it/s, resid=6.69E-05]
#
# LinearLeastSquares:  75%|███████▌  | 75/100 [00:01<00:00, 40.03it/s, resid=6.69E-05]
#
# LinearLeastSquares:  75%|███████▌  | 75/100 [00:01<00:00, 40.03it/s, resid=6.52E-05]
#
# LinearLeastSquares:  76%|███████▌  | 76/100 [00:01<00:00, 40.03it/s, resid=6.36E-05]
#
# LinearLeastSquares:  77%|███████▋  | 77/100 [00:01<00:00, 40.03it/s, resid=6.21E-05]
#
# LinearLeastSquares:  78%|███████▊  | 78/100 [00:01<00:00, 40.03it/s, resid=6.05E-05]
#
# LinearLeastSquares:  79%|███████▉  | 79/100 [00:01<00:00, 40.03it/s, resid=5.91E-05]
#
# LinearLeastSquares:  80%|████████  | 80/100 [00:01<00:00, 40.63it/s, resid=5.91E-05]
#
# LinearLeastSquares:  80%|████████  | 80/100 [00:01<00:00, 40.63it/s, resid=5.76E-05]
#
# LinearLeastSquares:  81%|████████  | 81/100 [00:01<00:00, 40.63it/s, resid=5.62E-05]
#
# LinearLeastSquares:  82%|████████▏ | 82/100 [00:01<00:00, 40.63it/s, resid=5.49E-05]
#
# LinearLeastSquares:  83%|████████▎ | 83/100 [00:01<00:00, 40.63it/s, resid=5.36E-05]
#
# LinearLeastSquares:  84%|████████▍ | 84/100 [00:01<00:00, 40.63it/s, resid=5.23E-05]
#
# LinearLeastSquares:  85%|████████▌ | 85/100 [00:01<00:00, 40.40it/s, resid=5.23E-05]
#
# LinearLeastSquares:  85%|████████▌ | 85/100 [00:02<00:00, 40.40it/s, resid=5.11E-05]
#
# LinearLeastSquares:  86%|████████▌ | 86/100 [00:02<00:00, 40.40it/s, resid=4.99E-05]
#
# LinearLeastSquares:  87%|████████▋ | 87/100 [00:02<00:00, 40.40it/s, resid=4.87E-05]
#
# LinearLeastSquares:  88%|████████▊ | 88/100 [00:02<00:00, 40.40it/s, resid=4.76E-05]
#
# LinearLeastSquares:  89%|████████▉ | 89/100 [00:02<00:00, 40.40it/s, resid=4.65E-05]
#
# LinearLeastSquares:  90%|█████████ | 90/100 [00:02<00:00, 40.60it/s, resid=4.65E-05]
#
# LinearLeastSquares:  90%|█████████ | 90/100 [00:02<00:00, 40.60it/s, resid=4.54E-05]
#
# LinearLeastSquares:  91%|█████████ | 91/100 [00:02<00:00, 40.60it/s, resid=4.44E-05]
#
# LinearLeastSquares:  92%|█████████▏| 92/100 [00:02<00:00, 40.60it/s, resid=4.33E-05]
#
# LinearLeastSquares:  93%|█████████▎| 93/100 [00:02<00:00, 40.60it/s, resid=4.24E-05]
#
# LinearLeastSquares:  94%|█████████▍| 94/100 [00:02<00:00, 40.60it/s, resid=4.14E-05]
#
# LinearLeastSquares:  95%|█████████▌| 95/100 [00:02<00:00, 39.93it/s, resid=4.14E-05]
#
# LinearLeastSquares:  95%|█████████▌| 95/100 [00:02<00:00, 39.93it/s, resid=4.05E-05]
#
# LinearLeastSquares:  96%|█████████▌| 96/100 [00:02<00:00, 39.93it/s, resid=3.96E-05]
#
# LinearLeastSquares:  97%|█████████▋| 97/100 [00:02<00:00, 39.93it/s, resid=3.87E-05]
#
# LinearLeastSquares:  98%|█████████▊| 98/100 [00:02<00:00, 39.93it/s, resid=3.79E-05]
#
# LinearLeastSquares:  99%|█████████▉| 99/100 [00:02<00:00, 39.93it/s, resid=3.70E-05]
#
# LinearLeastSquares: 100%|██████████| 100/100 [00:02<00:00, 40.91it/s, resid=3.70E-05]

# %%
import sigpy.mri

# %%
sens_map = sigpy.mri.espirit_maps(ksp=kspace_low_dim,device=gpu_number)

# %%
pl.ImagePlot(sens_map)
# Out:
# <img src="data:image/png;base64,..." width="431.8749935645611">

# %%
fft_low_dim = sp.ifft(kspace_low_dim,axes=[-2,-1])

# %%
pl.ImagePlot(fft_low_dim)
# Out:
# <img src="data:image/png;base64,..." width="431.8749935645611">

# %%
pl.ImagePlot(kspace_low_dim)
# Out:
# <img src="data:image/png;base64,..." width="431.8749935645611">

# %%
pl.ScatterPlot(cc1)
# Out:
# <img src="data:image/png;base64,..." width="216">

# %%
ses_maps_

# %%
S = sp.linop.Multiply((1,300,300),sens_maps_t)
NUFFT = sp.linop.NUFFT((12,300,300),coor)
Operator = NUFFT*S

# %%
W = sp.linop.Wavelet((1,300,300),axes = [-1,-2])
lamda = 0.000001
proxg = sp.prox.UnitaryTransform(sp.prox.L1Reg(W.oshape, lamda), W)

# %%
phase
# Out:
# array(-1.+1.2246468e-16j)

# %%
pl.ImagePlot(img_rec_now_2)
# Out:
# <img src="data:image/png;base64,..." width="288">

# %%
coor_subsample_2[:,:,1][None,:,:]
# Out:
# (512, 96)

# %%
rawdata_brain.shape
# Out:
# (12, 512, 96)

# %%
coor.shape
# Out:
# (512, 96, 2)

# %%
pl.ImagePlot(sens_maps_t)
# Out:
# <img src="data:image/png;base64,..." width="431.8749935645611">

# %%
sens_map

# %%
# Subsample of the radial data
#L_2 Normalization
lamda_l2 = 0.1
proxg_l2 = sp.prox.L2Reg((1,300,300),lamda_l2)
coor_subsample_2 = coor[:,::1,:]
# phase = np.exp(1j*np.pi*(0)*coor_subsample_2[:,:,0][None,:,:])
# phase = sp.backend.to_device(phase,gpu_number)
rawdata_brain_2 = rawdata_brain[:,:,::1]
rawdata_brain_2 = sp.backend.to_device(rawdata_brain_2,gpu_number)
# pl.ScatterPlot(coor_subsample_2)
S_2 = sp.linop.Multiply((1,300,300),sens_maps_t)
NUFFT_2 = sp.linop.NUFFT((12,300,300),coor_subsample_2)
Operator_2 = NUFFT_2*S_2
img_rec_now_2 = sp.app.LinearLeastSquares(Operator_2,rawdata_brain_2,proxg=proxg_l2,max_iter=100).run()
img_rec_now_2 = sp.backend.to_device(img_rec_now_2)
im_abs_recon_now_2 = abs(img_rec_now_2[0,:,:])
plt.figure(figsize=(20,10))
plt.title("Reconstruction without l1-Wavelet Regularization (undersampled by factor %d)"%10)
plt.imshow(im_abs_recon_now_2[::-1,:],cmap='gray')
plt.show()
# Out:
# MaxEig: 100%|██████████| 30/30 [00:00<00:00, 45.75it/s, max_eig=8.99E+01]
# LinearLeastSquares: 100%|██████████| 100/100 [00:02<00:00, 44.00it/s, resid=3.41E-04]
# <img src="data:image/png;base64,..." width="720">
